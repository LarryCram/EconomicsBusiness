# %%
import duckdb
import pandas as pd
from pathlib import Path
import diskcache
from itertools import chain
from collections import Counter

import igraph as ig
import matplotlib.pyplot as plt
import seaborn.objects as so
import seaborn as sns

from utils.pandas_setup import pandas_setup
pandas_setup()

import pyalex
from pyalex import Works, Authors, Sources, Institutions, Topics, Publishers, Funders
pyalex.config.email = "Lawrence.Cram@anu.edu.au"
pyalex.config.max_retries = 0
pyalex.config.retry_backoff_factor = 0.1
pyalex.config.retry_http_codes = [429, 500, 503]

MY_DATA_PATH = Path('../DATA/')
MY_DATABASE_FILE = Path(MY_DATA_PATH / 'econ.duckdb')
MY_CACHE_FILE = Path('/home/lc/m/.cache/econommicsbusiness/cache.db')
DATAFILES_PATH = Path('../DATAFILES')

# %%
class SetUp:

    def __init__(self):
        self._setup_db()
        self._setup_cache()
        return
    
    def _setup_db(self):
        self.db = duckdb.connect(MY_DATABASE_FILE)
        self.db.sql("ATTACH IF NOT EXISTS ':memory:'")
        self.db.sql(""" SET memory_limit = '56GB';
                        SET threads = 6;
                        SET preserve_insertion_order = false;
                        SET order_by_non_integer_literal=true;
                        SET enable_progress_bar = true;
                        SET temp_directory = '/home/lc/m/.tmp';
                    """)
        self.db.sql("SHOW ALL TABLES").show()
        return
    
    def _setup_cache(self):
        self.cache = diskcache.Cache(MY_CACHE_FILE, size_limit=16_000_000_000)
        print(f'{self.cache.check() = }')
        print(f'{self.cache.volume() = }')
        return
    
    def name_of_global_obj(self, obj=None):
        for objname, oid in globals().items():
            if oid is obj:
                return objname

# %%
class CoauthorshipNetwork(SetUp):

    def __init__(self):
        super().__init__()
        return
    
    def build_authorship_network(self):
        # get works from a few small, top  journals
        source_list = 'https://openalex.org/S2764736659 https://openalex.org/S7397502'
        sql = f"""
                CREATE OR REPLACE TABLE memory.network AS 
                    SELECT replace(source_id, 'https://openalex.org/', '') AS source_id,
                            -- any_value(source_name),
                            replace(institution_id, 'https://openalex.org/', '') AS institution_id,
                            -- any_value(institution_name)
                            count(work_id) AS weight,
                        FROM works w
                        LEFT JOIN authorships a
                            USING (work_id) 
                            WHERE contains('{source_list}', w.source_id) = true 
                                    AND author_name NOT NULL
                                    AND work_id NOT NULL
                        GROUP BY source_id, institution_id, source_name, institution_name
                        ORDER BY weight DESC, source_name, institution_name
            """
        self.db.sql(sql)
        self.db.sql("SELECT * FROM memory.network").show()
        self.db.sql("COPY memory.network TO '../DATA/NETWORK_DATA/trial.csv' (HEADER false, DELIMITER '\t')")
        return
    
    def extract_graph(self):
        self.g = ig.Graph.Read_Ncol('../DATA/NETWORK_DATA/trial.csv', names=True)
        print(self.g.get_edgelist())
        print(self.g.es["weight"])
        print(self.g.vs["name"])
        return
    
    def pagerank(self):
        ranks = self.g.pagerank()
        print(ranks)
        return

# %%
class CitationNetwork(SetUp):

    def __init__(self, kind=None):
        super().__init__()
        self.kind = kind
        return
    
    def journal_edge_ist(self):
        # create a table for each eligible work, and the associated journal and institution information
        sql = """
                CREATE OR REPLACE TABLE econ.base AS
                    (SELECT DISTINCT 
                            w.work_id,
                            1.0 AS citation_weight,
                            w.publication_year,
                            'source' AS kind,
                            w.source_id AS id,
                            w.source_name AS name,
                            w.host_name AS name_ext,
                            count(DISTINCT institution_id) AS institutions_distinct_count
                        FROM works w
                            LEFT JOIN authorships a
                                USiNG (work_id)
                        WHERE contains('article review preprint letter', w.type) = true 
                            AND publication_year >= 2010
                            AND institutions_distinct_count > 0
                            AND id NOT NULL
                        GROUP BY ALL
                        )
                    UNION ALL
                    (SELECT DISTINCT 
                            w.work_id,
                            1.0/count(DISTINCT institution_id) AS citation_weight,
                            w.publication_year,
                            'institution' AS kind,
                            a.institution_id AS id,
                            a.institution_name AS name,
                            a.country_code AS name_ext,
                            count(DISTINCT institution_id) AS institutions_distinct_count
                        FROM works w
                            LEFT JOIN authorships a
                                USiNG (work_id)
                        WHERE contains('article review preprint letter', w.type) = true 
                            AND publication_year >= 2010
                            AND institutions_distinct_count > 0
                            AND id NOT NULL

                        GROUP BY ALL
                        )
                    ORDER BY work_id
            """
        self.db.sql(sql)  #.show()
        # self._build_name_dictionaries()
        return
    
    def _build_name_dictionaries(self):
        # build dictionarys to find names associated with ID codes for sources and institutions
        df = self.db.sql("SELECT * FROM econ.base").df()
        self.name = {**dict(zip(df.source_id, df.source_name)), **dict(zip(df.institution_id, df.institution_name))}
        self.name_ext = {**dict(zip(df.source_id, df.host_name)), **dict(zip(df.institution_id, df.country_code))}
        return
    
    def report_base(self):
        for kind in ['source', 'institution']:
            print(f'\n>>BASE table for {kind = }')
            df = self.db.sql(f"SELECT * FROM econ.base WHERE kind = '{kind}'").df()
            print(f'{df.shape = }\n{df.head()}')
            print(f'{df.work_id.nunique() = }')
            print(f'{df.id.nunique() = }')
            print(f'{df.name.nunique() = }')
            print(f'{df.name_ext.nunique() = }')                        
        return
    
    def build_citations(self):
        for citer_kind in ['source', 'institution']:
            print(f'build citations {citer_kind = }')
            sql = f"""
                    CREATE OR REPLACE TABLE econ.citations_{citer_kind} AS 
                    SELECT 
                            DISTINCT sub.citer_id,
                            sub.name AS citer_name,
                            sub.kind AS citer_kind,
                            sub.cited_id,
                            bb.name AS cited_name,
                            bb.kind AS cited_kind
                        FROM
                            (
                            SELECT b.work_id AS citer_id,
                                b.name,
                                b.kind,
                                unnest(referenced_works) AS cited_id,
                            FROM econ.base b
                            LEFT JOIN cited c
                            ON c.work_id = b.work_id
                                AND b.kind = '{citer_kind}'
                            WHERE b.work_id = 'https://openalex.org/W1000079159'
                            ) sub
                            LEFT JOIN econ.base bb
                            ON sub.cited_id = bb.work_id
                                AND bb.kind = '{citer_kind}'                            
                            WHERE bb.name NOT NULL 

                """
            self.db.sql(sql)
            self.db.sql(f"SELECT * FROM econ.citations_{citer_kind} ORDER BY citer_id, cited_id, citer_kind").show()
            self.db.sql(f"SELECT count(cited_id), count(DISTINCT citer_id), count(DISTINCT cited_id) FROM econ.citations_{citer_kind}").show()
        return
    
    def check_institution_weight(self):
        for citer_kind in ['source', 'institution']:
            print(f'check institution weight {citer_kind = }')
            sql = f""" 
                    SELECT * --, bb.id 
                    FROM
                        (
                        SELECT --b.citation_weight*bb.citation_weight,
                            c.citer_id AS citer_work_id,
                            c.cited_id AS cited_work_id, 
                            b.id AS citer_id,
                        FROM econ.citations_{citer_kind} c
                        LEFT JOIN econ.base b
                            ON c.citer_id = b.work_id
                                AND b.kind = '{citer_kind}'
                        ) sub
                    LEFT JOIN econ.base bb
                        ON sub.cited_work_id = bb.work_id
                            AND bb.kind = '{citer_kind}'
                    --GROUP BY b.id, bb.id
                    ORDER BY citer_work_id ASC
                    """
            self.db.sql(sql).show()
        return
    
    def build_edge_list(self):
        # build table of citation counts between citer and cited (journals and institutions)
        for citer_kind in ['source', 'institution']:
            print(f'build edge list {citer_kind = }')
            self.db.sql("SELECT * FROM econ.citations ORDER BY citer_id, cited_id, citer_kind").show()
            self.db.sql("SELECT count(cited_id), count(DISTINCT citer_id), count(DISTINCT cited_id) FROM econ.citations").show()
            sql = f"""
                    CREATE OR REPLACE TABLE econ.citation_network_{citer_kind} AS 
                        SELECT sum(b.citation_weight*bb.citation_weight) AS weights,
                                b.id AS citer,
                                bb.id AS cited
                            FROM econ.citations c
                            LEFT JOIN econ.base b
                                ON c.citer_id = b.work_id
                                LEFT JOIN econ.base bb
                                    ON c.cited_id = bb.work_id
                                    WHERE bb.kind = '{citer_kind}'
                                            AND b.kind = '{citer_kind}'
                                            --AND bb.publication_year < 2011
                            GROUP BY b.id, bb.id
                            ORDER BY weights ASC     
                """
            self.db.sql(sql)
        return        

    def report_citations(self):
        for citer_kind in ['source', 'institution']:
            print(f'{citer_kind = }')
            df = self.db.sql(f"SELECT * FROM econ.citation_network_{citer_kind}").df()
            df = df[df.weights > 0].sort_values('weights', ascending=False).reset_index(drop=True)
            print(f'{df.shape = }\n{df.head()}')
            print(f'DISTINCT CITERS {df.citer.nunique() = }')
            print(f'DISTINCT CITEDS {df.cited.nunique() = }')
            print(f'TOTAL CITATIONS {df.weights.sum() = }')
        return
    
    def extract_citation_tables(self):
        for citer_kind in ['source', 'institution', 'both']:
                                        # ('both', 'source'), ('both', 'institution'), 
                                        # ('source', 'both'), ('institution', 'both'),
                                        # ('both', 'both)')]:
            print(f'{citer_kind = }')
            # if 'both' not in [citer_kind, cited_kind]?
            self.extract_graph(citer_kind)
            self.run_pagerank(citer_kind)
            self.report_pagerank(citer_kind)
            self.weighted_citation_count(citer_kind)
            # self.plot_model(citer_kind)
        return

    def extract_graph(self, citer_kind):
        if citer_kind == 'both':
            df1 = pd.read_csv('../DATA/NETWORK_DATA/citation_network_source.csv')
            df2 = pd.read_csv('../DATA/NETWORK_DATA/citation_network_institution.csv')
            df2['weights'] = [int(w) if isinstance(w, float) else 0 for w in df2.reweights]
            df_edges = pd.concat([df1, df2], axis=0)
        else:
            df_edges = pd.read_csv(f'../DATA/NETWORK_DATA/citation_network_{citer_kind}.csv')
            if citer_kind == 'institution':
                    df_edges['weights'] = [int(w) if isinstance(w, float) else 0 for w in df_edges.reweights]
        df_edges = df_edges[df_edges.weights >= 50]
        print(f'*** DROP EDGES WITH FEWER THAN 50 CITATIONS {df_edges.shape = }\n{df_edges.head()}')
        self.g = ig.Graph.DataFrame(df_edges, directed=True, use_vids=False)
        print(self.g.get_edgelist())
        summary = ig.summary(self.g, verbosity=0, width=78, edge_list_format='auto', max_rows=99999, print_graph_attributes=False, 
                                          print_vertex_attributes=False, print_edge_attributes=False, full=False)
        print(f'*** SUMMARY OF self.g\n{summary}')
        return
    
    def run_pagerank(self, citer_kind):
        print('pageRank')
        ranks = self.g.pagerank(weights='weights', implementation='power')
        print(f'>> CHECK pageRank  - should sum to unity {sum(ranks) = }')
        rank_max = max(ranks)
        ranks = [10.*r/rank_max for r in ranks]
        self.pagerank = pd.DataFrame(zip(ranks, self.g.vs["name"], self.g.degree()), columns=['pageRank','citer', 'pub_count']).sort_values('pageRank', ascending=False)
        temp = self.pagerank
        self.db.sql(f"CREATE OR REPLACE TABLE econ.pagerank_{citer_kind} AS SELECT * FROM temp")
        return
    
    def report_pagerank(self, citer_kind):        
        self.pagerank['name'] = [self.name.get(id) for id in self.pagerank['citer']]
        self.pagerank['name_ext'] = [self.name_ext.get(id) for id in self.pagerank['citer']]
        self.db.sql(f"SELECT * FROM econ.pagerank_{citer_kind}").show()
        print(f'{self.pagerank.shape = }\n{self.pagerank.head(8)}')
        print(f'\n{self.pagerank.tail(8)}')
        print(f'Sum of publications {self.pagerank['pub_count'].sum() = }')
        print(f'Sum of pageranks {self.pagerank['pageRank'].sum() = }')
        self.db.sql("SELECT count(DISTINCT work_id) AS original_works_count FROM works").show()
        return

    def weighted_citation_count(self, citer_kind):
        self.db.sql("SELECT * FROM memory.base").show()
        sql = """ 
                (SELECT b.work_id AS citer_id,
                        unnest(referenced_works) AS cited_id,
                        author_id, 
                        author_name,
                        source_id,
                        institution_id,
                    FROM memory.base b
                    LEFT JOIN cited c
                        USING (work_id)
                    LIMIT 64
                """
        self.db.sql(sql).show()
        return

        # sql = f"""
        #         CREATE OR REPlACE TABLE econ.citation_counts AS
        #             SELECT count(b2.work_id) AS citation_counts,
        #                     sum(p.pagerank) AS weighted_citation_counts,
        #                     b2.author_id AS cited_id,
        #                     b2.author_name AS cited_name,
        #                 FROM
        #                 (
        #                 SELECT c.work_id AS citer_id, 
        #                         unnest(referenced_works) AS cited_id,
        #                         b1.{citer_kind}_id AS citer,
        #                         b1.source_id
        #                     FROM cited c
        #                     LEFT JOIN memory.base b1
        #                         ON c.work_id = b1.work_id
        #                 ) sub
        #                     LEFT JOIN memory.base b2
        #                         ON sub.cited_id = b2.work_id
        #                         LEFT JOIN pagerank_{citer_kind} p
        #                             ON sub.citer = p.citer
        #                 WHERE p.citer NOT NULL AND b2.author_id NOT NULL
        #             GROUP BY ALL
        #             ORDER BY citation_counts DESC
        #     """ 
        # self.db.sql(sql)
        # self.db.sql("SELECT * FROM econ.citation_counts").show()
        # return
    
    def plot_model(self, citer_kind):
        df = self.db.sql("SELECT * FROM econ.citation_counts").df().sort_values('weighted_citation_counts', ascending=False)
        sample = self.db.sql("SELECT * FROM econ.").df()
        dd = dict(zip(sample.author_id, sample.Group))
        print(f'{dd = }')
        df['group'] = [dd.get(aid, 'X') for aid in df.cited_id]
        df['pointsize'] = [0.01 if g == 'X' else 10 for g in df.group]
        df = df.sort_values(['group', 'pointsize'], ascending=[False, True])
        fig, ax = plt.subplots(1, 1)
        sns.scatterplot(df, x='citation_counts', y='weighted_citation_counts', hue='group', size='pointsize')
        ax.set_yscale('log')
        ax.set_xscale('log')
        ax.set_xlim((100, 50000))
        ax.set_ylim((100, 50000))
        hand, lab = ax.get_legend_handles_labels()
        lab[0] = 'Group'
        ax.legend()
        ax.legend(handles=list(hand[:4]), labels=list(lab[:4]), loc=2)
        ax.set_title(f'{citer_kind.title()}s citing {citer_kind}s')
        plt.show()
        return

# %%
def main():

    # cn = CoauthorshipNetwork()
    # cn.build_authorship_network()
    # cn.extract_graph()
    # cn.pagerank()

    kind = 'source'
    # kind = 'institution'
    cn = CitationNetwork(kind=kind)
    # cn.build_base()
    # cn.report_base()
    cn.build_citations()
    cn.check_institution_weight()
 
    # cn.build_edge_list()    
    # cn.report_citations()
    # cn.extract_citation_tables()
    return

# %%
if __name__ == "__main__":
    main()
    print("DONE!")
# Out:
# ┌──────────┬─────────┬──────────────────────────────────┬──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┬────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┬───────────┐
# │ database │ schema  │               name               │                                                                                                                                                                                                 column_names                                                                                                                                                                                                 │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        column_types                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        │ temporary │
# │ varchar  │ varchar │             varchar              │                                                                                                                                                                                                  varchar[]                                                                                                                                                                                                   │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         varchar[]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          │  boolean  │
# ├──────────┼─────────┼──────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────┤
# │ econ     │ main    │ authorships                      │ [work_id, author_id, author_name, orcid, institution_id, institution_name, ror, country_code, type]                                                                                                                                                                                                                                                                                                          │ [VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          │ false     │
# │ econ     │ main    │ base                             │ [work_id, citation_weight, publication_year, kind, id, name, name_ext, institutions_distinct_count]                                                                                                                                                                                                                                                                                                          │ [VARCHAR, DOUBLE, BIGINT, VARCHAR, VARCHAR, VARCHAR, VARCHAR, BIGINT]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      │ false     │
# │ econ     │ main    │ citation_counts                  │ [citation_counts, weighted_citation_counts, cited_id, cited_name]                                                                                                                                                                                                                                                                                                                                            │ [BIGINT, DOUBLE, VARCHAR, VARCHAR]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         │ false     │
# │ econ     │ main    │ citation_network_institution     │ [weights, citer, cited]                                                                                                                                                                                                                                                                                                                                                                                      │ [DOUBLE, VARCHAR, VARCHAR]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 │ false     │
# │ econ     │ main    │ citation_network_source          │ [weights, citer, cited]                                                                                                                                                                                                                                                                                                                                                                                      │ [DOUBLE, VARCHAR, VARCHAR]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 │ false     │
# │ econ     │ main    │ citations                        │ [citer_id, citer_name, citer_kind, cited_id, cited_name, cited_kind]                                                                                                                                                                                                                                                                                                                                         │ [VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     │ false     │
# │ econ     │ main    │ citations_institution            │ [citer_id, citer_name, citer_kind, cited_id, cited_name, cited_kind]                                                                                                                                                                                                                                                                                                                                         │ [VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     │ false     │
# │ econ     │ main    │ citations_source                 │ [citer_id, citer_name, citer_kind, cited_id, cited_name, cited_kind]                                                                                                                                                                                                                                                                                                                                         │ [VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     │ false     │
# │ econ     │ main    │ cited                            │ [work_id, referenced_works]                                                                                                                                                                                                                                                                                                                                                                                  │ [VARCHAR, VARCHAR[]]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       │ false     │
# │ econ     │ main    │ pagerank_both                    │ [pageRank, citer, pub_count]                                                                                                                                                                                                                                                                                                                                                                                 │ [DOUBLE, VARCHAR, BIGINT]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  │ false     │
# │ econ     │ main    │ pagerank_institution             │ [pageRank, citer, pub_count]                                                                                                                                                                                                                                                                                                                                                                                 │ [DOUBLE, VARCHAR, BIGINT]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  │ false     │
# │ econ     │ main    │ pagerank_institution_institution │ [pageRank, citer, pub_count]                                                                                                                                                                                                                                                                                                                                                                                 │ [DOUBLE, VARCHAR, BIGINT]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  │ false     │
# │ econ     │ main    │ pagerank_institution_source      │ [pageRank, citer, pub_count]                                                                                                                                                                                                                                                                                                                                                                                 │ [DOUBLE, VARCHAR, BIGINT]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  │ false     │
# │ econ     │ main    │ pagerank_source                  │ [pageRank, citer, pub_count]                                                                                                                                                                                                                                                                                                                                                                                 │ [DOUBLE, VARCHAR, BIGINT]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  │ false     │
# │ econ     │ main    │ pagerank_source_institution      │ [pageRank, citer, pub_count]                                                                                                                                                                                                                                                                                                                                                                                 │ [DOUBLE, VARCHAR, BIGINT]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  │ false     │
# │ econ     │ main    │ pagerank_source_source           │ [pageRank, citer, pub_count]                                                                                                                                                                                                                                                                                                                                                                                 │ [DOUBLE, VARCHAR, BIGINT]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  │ false     │
# │ econ     │ main    │ sample_names                     │ [Research_Profile, author_id, author_name, Group, CIT, PUB, HCP, last, works_count]                                                                                                                                                                                                                                                                                                                          │ [VARCHAR, VARCHAR, VARCHAR, VARCHAR, BIGINT, BIGINT, BIGINT, VARCHAR, BIGINT]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              │ false     │
# │ econ     │ main    │ samples                          │ [Research_Profile, ACR, PUB, CIT, HCP, suma, coc, score, Group, first, last]                                                                                                                                                                                                                                                                                                                                 │ [VARCHAR, VARCHAR, BIGINT, BIGINT, BIGINT, DOUBLE, DOUBLE, DOUBLE, VARCHAR, VARCHAR, VARCHAR]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              │ false     │
# │ econ     │ main    │ sources_oa_incites               │ [id, issn_l, issn, display_name, host_organization, host_organization_name, host_organization_lineage, works_count, cited_by_count, summary_stats, is_oa, is_in_doaj, is_indexed_in_scopus, is_core, ids, homepage_url, apc_prices, apc_usd, country_code, societies, alternate_titles, abbreviated_title, type, topics, topic_share, x_concepts, counts_by_year, works_api_url, updated_date, created_date] │ [VARCHAR, VARCHAR, VARCHAR[], VARCHAR, VARCHAR, VARCHAR, VARCHAR[], BIGINT, BIGINT, STRUCT("2yr_mean_citedness" DOUBLE, h_index INTEGER, i10_index INTEGER), BOOLEAN, BOOLEAN, BOOLEAN, BOOLEAN, VARCHAR, VARCHAR, STRUCT(price INTEGER, currency VARCHAR)[], DOUBLE, VARCHAR, STRUCT(url VARCHAR, organization VARCHAR)[], VARCHAR[], VARCHAR, VARCHAR, STRUCT(id VARCHAR, display_name VARCHAR, count INTEGER, subfield STRUCT(id VARCHAR, display_name VARCHAR), field STRUCT(id VARCHAR, display_name VARCHAR), "domain" STRUCT(id VARCHAR, display_name VARCHAR))[], STRUCT(id VARCHAR, display_name VARCHAR, "value" DOUBLE, subfield STRUCT(id VARCHAR, display_name VARCHAR), field STRUCT(id VARCHAR, display_name VARCHAR), "domain" STRUCT(id VARCHAR, display_name VARCHAR))[], STRUCT(id VARCHAR, wikidata VARCHAR, display_name VARCHAR, "level" INTEGER, score DOUBLE)[], STRUCT("year" INTEGER, works_count INTEGER, cited_by_count INTEGER)[], VARCHAR, VARCHAR, VARCHAR] │ false     │
# │ econ     │ main    │ works                            │ [work_id, doi, title, display_name, publication_year, type, countries_distinct_count, institutions_distinct_count, fwci, has_fulltext, cited_by_count, is_retracted, is_paratext, referenced_works_count, cited_by_api_url, updated_date, created_date, is_authors_truncated, volume, issue, first_page, last_page, source_id, source_name, host_id, host_name]                                              │ [VARCHAR, VARCHAR, VARCHAR, VARCHAR, BIGINT, VARCHAR, BIGINT, BIGINT, DOUBLE, BOOLEAN, BIGINT, BOOLEAN, BOOLEAN, BIGINT, VARCHAR, VARCHAR, VARCHAR, BOOLEAN, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       │ false     │
# ├──────────┴─────────┴──────────────────────────────────┴──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┴────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┴───────────┤
# │ 20 rows                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             6 columns │
# └───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
#
# self.cache.check() = []
# self.cache.volume() = 4533873658
# build citations citer_kind = 'source'
# ┌──────────────────────────────────┬──────────────────────────────────────────────────┬────────────┬──────────────────────────────────┬──────────────────────────────────────────────────┬────────────┐
# │             citer_id             │                    citer_name                    │ citer_kind │             cited_id             │                    cited_name                    │ cited_kind │
# │             varchar              │                     varchar                      │  varchar   │             varchar              │                     varchar                      │  varchar   │
# ├──────────────────────────────────┼──────────────────────────────────────────────────┼────────────┼──────────────────────────────────┼──────────────────────────────────────────────────┼────────────┤
# │ https://openalex.org/W1000079159 │ International Journal of Industrial Organization │ source     │ https://openalex.org/W1536446786 │ The Review of Economics and Statistics           │ source     │
# │ https://openalex.org/W1000079159 │ International Journal of Industrial Organization │ source     │ https://openalex.org/W2076356822 │ International Journal of Industrial Organization │ source     │
# │ https://openalex.org/W1000079159 │ International Journal of Industrial Organization │ source     │ https://openalex.org/W2093319394 │ Review of Industrial Organization                │ source     │
# │ https://openalex.org/W1000079159 │ International Journal of Industrial Organization │ source     │ https://openalex.org/W2111980175 │ Scandinavian Journal of Economics                │ source     │
# │ https://openalex.org/W1000079159 │ International Journal of Industrial Organization │ source     │ https://openalex.org/W2125933729 │ Energy Economics                                 │ source     │
# │ https://openalex.org/W1000079159 │ International Journal of Industrial Organization │ source     │ https://openalex.org/W2141795829 │ Journal of Industrial Economics                  │ source     │
# │ https://openalex.org/W1000079159 │ International Journal of Industrial Organization │ source     │ https://openalex.org/W2147625786 │ The Energy Journal                               │ source     │
# │ https://openalex.org/W1000079159 │ International Journal of Industrial Organization │ source     │ https://openalex.org/W3123841633 │ Economic Record                                  │ source     │
# │ https://openalex.org/W1000079159 │ International Journal of Industrial Organization │ source     │ https://openalex.org/W3123911682 │ Economics Letters                                │ source     │
# │ https://openalex.org/W1000079159 │ International Journal of Industrial Organization │ source     │ https://openalex.org/W3124690063 │ Energy Economics                                 │ source     │
# │ https://openalex.org/W1000079159 │ International Journal of Industrial Organization │ source     │ https://openalex.org/W3125343438 │ The Energy Journal                               │ source     │
# ├──────────────────────────────────┴──────────────────────────────────────────────────┴────────────┴──────────────────────────────────┴──────────────────────────────────────────────────┴────────────┤
# │ 11 rows                                                                                                                                                                                   6 columns │
# └─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
#
# ┌─────────────────┬──────────────────────────┬──────────────────────────┐
# │ count(cited_id) │ count(DISTINCT citer_id) │ count(DISTINCT cited_id) │
# │      int64      │          int64           │          int64           │
# ├─────────────────┼──────────────────────────┼──────────────────────────┤
# │              11 │                        1 │                       11 │
# └─────────────────┴──────────────────────────┴──────────────────────────┘
#
# build citations citer_kind = 'institution'
# ┌──────────────────────────────────┬───────────────────────┬─────────────┬──────────────────────────────────┬─────────────────────────────────────────┬─────────────┐
# │             citer_id             │      citer_name       │ citer_kind  │             cited_id             │               cited_name                │ cited_kind  │
# │             varchar              │        varchar        │   varchar   │             varchar              │                 varchar                 │   varchar   │
# ├──────────────────────────────────┼───────────────────────┼─────────────┼──────────────────────────────────┼─────────────────────────────────────────┼─────────────┤
# │ https://openalex.org/W1000079159 │ Texas Tech University │ institution │ https://openalex.org/W1536446786 │ University of California, San Diego     │ institution │
# │ https://openalex.org/W1000079159 │ Texas Tech University │ institution │ https://openalex.org/W1536446786 │ The Ohio State University               │ institution │
# │ https://openalex.org/W1000079159 │ Texas Tech University │ institution │ https://openalex.org/W2076356822 │ The Ohio State University               │ institution │
# │ https://openalex.org/W1000079159 │ Texas Tech University │ institution │ https://openalex.org/W2093319394 │ Federal Trade Commission                │ institution │
# │ https://openalex.org/W1000079159 │ Texas Tech University │ institution │ https://openalex.org/W2111980175 │ Center for Economic and Policy Research │ institution │
# │ https://openalex.org/W1000079159 │ Texas Tech University │ institution │ https://openalex.org/W2111980175 │ Norwegian School of Economics           │ institution │
# │ https://openalex.org/W1000079159 │ Texas Tech University │ institution │ https://openalex.org/W2125933729 │ University of California, San Diego     │ institution │
# │ https://openalex.org/W1000079159 │ Texas Tech University │ institution │ https://openalex.org/W2141795829 │ The Ohio State University               │ institution │
# │ https://openalex.org/W1000079159 │ Texas Tech University │ institution │ https://openalex.org/W2147625786 │ Mount Royal University                  │ institution │
# │ https://openalex.org/W1000079159 │ Texas Tech University │ institution │ https://openalex.org/W2147625786 │ University of Alberta                   │ institution │
# │ https://openalex.org/W1000079159 │ Texas Tech University │ institution │ https://openalex.org/W3123841633 │ The University of Sydney                │ institution │
# │ https://openalex.org/W1000079159 │ Texas Tech University │ institution │ https://openalex.org/W3123841633 │ Waseda University                       │ institution │
# │ https://openalex.org/W1000079159 │ Texas Tech University │ institution │ https://openalex.org/W3123911682 │ Curtin University                       │ institution │
# │ https://openalex.org/W1000079159 │ Texas Tech University │ institution │ https://openalex.org/W3124690063 │ Texas Tech University                   │ institution │
# │ https://openalex.org/W1000079159 │ Texas Tech University │ institution │ https://openalex.org/W3125343438 │ Queen's University                      │ institution │
# │ https://openalex.org/W1000079159 │ Texas Tech University │ institution │ https://openalex.org/W3125343438 │ Stanford University                     │ institution │
# ├──────────────────────────────────┴───────────────────────┴─────────────┴──────────────────────────────────┴─────────────────────────────────────────┴─────────────┤
# │ 16 rows                                                                                                                                                 6 columns │
# └───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
#
# ┌─────────────────┬──────────────────────────┬──────────────────────────┐
# │ count(cited_id) │ count(DISTINCT citer_id) │ count(DISTINCT cited_id) │
# │      int64      │          int64           │          int64           │
# ├─────────────────┼──────────────────────────┼──────────────────────────┤
# │              16 │                        1 │                       11 │
# └─────────────────┴──────────────────────────┴──────────────────────────┘
#
# check institution weight citer_kind = 'source'
# ┌──────────────────────────────────┬──────────────────────────────────┬─────────────────────────────────┬──────────────────────────────────┬─────────────────┬──────────────────┬─────────┬─────────────────────────────────┬──────────────────────────────────────────────────┬─────────────────────────────────┬─────────────────────────────┐
# │          citer_work_id           │          cited_work_id           │            citer_id             │             work_id              │ citation_weight │ publication_year │  kind   │               id                │                       name                       │            name_ext             │ institutions_distinct_count │
# │             varchar              │             varchar              │             varchar             │             varchar              │     double      │      int64       │ varchar │             varchar             │                     varchar                      │             varchar             │            int64            │
# ├──────────────────────────────────┼──────────────────────────────────┼─────────────────────────────────┼──────────────────────────────────┼─────────────────┼──────────────────┼─────────┼─────────────────────────────────┼──────────────────────────────────────────────────┼─────────────────────────────────┼─────────────────────────────┤
# │ https://openalex.org/W1000079159 │ https://openalex.org/W3123911682 │ https://openalex.org/S183232449 │ https://openalex.org/W3123911682 │             1.0 │             2010 │ source  │ https://openalex.org/S36178057  │ Economics Letters                                │ Elsevier BV                     │                           1 │
# │ https://openalex.org/W1000079159 │ https://openalex.org/W2147625786 │ https://openalex.org/S183232449 │ https://openalex.org/W2147625786 │             1.0 │             2013 │ source  │ https://openalex.org/S102805530 │ The Energy Journal                               │ SAGE Publishing                 │                           2 │
# │ https://openalex.org/W1000079159 │ https://openalex.org/W3124690063 │ https://openalex.org/S183232449 │ https://openalex.org/W3124690063 │             1.0 │             2015 │ source  │ https://openalex.org/S94499970  │ Energy Economics                                 │ Elsevier BV                     │                           1 │
# │ https://openalex.org/W1000079159 │ https://openalex.org/W2093319394 │ https://openalex.org/S183232449 │ https://openalex.org/W2093319394 │             1.0 │             2012 │ source  │ https://openalex.org/S3416249   │ Review of Industrial Organization                │ Springer Science+Business Media │                           1 │
# │ https://openalex.org/W1000079159 │ https://openalex.org/W3125343438 │ https://openalex.org/S183232449 │ https://openalex.org/W3125343438 │             1.0 │             2014 │ source  │ https://openalex.org/S102805530 │ The Energy Journal                               │ SAGE Publishing                 │                           2 │
# │ https://openalex.org/W1000079159 │ https://openalex.org/W2111980175 │ https://openalex.org/S183232449 │ https://openalex.org/W2111980175 │             1.0 │             2013 │ source  │ https://openalex.org/S165253824 │ Scandinavian Journal of Economics                │ Wiley                           │                           2 │
# │ https://openalex.org/W1000079159 │ https://openalex.org/W2125933729 │ https://openalex.org/S183232449 │ https://openalex.org/W2125933729 │             1.0 │             2011 │ source  │ https://openalex.org/S94499970  │ Energy Economics                                 │ Elsevier BV                     │                           1 │
# │ https://openalex.org/W1000079159 │ https://openalex.org/W1536446786 │ https://openalex.org/S183232449 │ https://openalex.org/W1536446786 │             1.0 │             2011 │ source  │ https://openalex.org/S180061323 │ The Review of Economics and Statistics           │ The MIT Press                   │                           2 │
# │ https://openalex.org/W1000079159 │ https://openalex.org/W2076356822 │ https://openalex.org/S183232449 │ https://openalex.org/W2076356822 │             1.0 │             2011 │ source  │ https://openalex.org/S183232449 │ International Journal of Industrial Organization │ Elsevier BV                     │                           1 │
# │ https://openalex.org/W1000079159 │ https://openalex.org/W3123841633 │ https://openalex.org/S183232449 │ https://openalex.org/W3123841633 │             1.0 │             2013 │ source  │ https://openalex.org/S130179515 │ Economic Record                                  │ Wiley                           │                           2 │
# │ https://openalex.org/W1000079159 │ https://openalex.org/W2141795829 │ https://openalex.org/S183232449 │ https://openalex.org/W2141795829 │             1.0 │             2011 │ source  │ https://openalex.org/S99067594  │ Journal of Industrial Economics                  │ Wiley                           │                           1 │
# ├──────────────────────────────────┴──────────────────────────────────┴─────────────────────────────────┴──────────────────────────────────┴─────────────────┴──────────────────┴─────────┴─────────────────────────────────┴──────────────────────────────────────────────────┴─────────────────────────────────┴─────────────────────────────┤
# │ 11 rows                                                                                                                                                                                                                                                                                                                           11 columns │
# └──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
#
# check institution weight citer_kind = 'institution'
# ┌──────────────────────────────────┬──────────────────────────────────┬────────────────────────────────┬──────────────────────────────────┬─────────────────┬──────────────────┬─────────────┬──────────────────────────────────┬─────────────────────────────────────────┬──────────┬─────────────────────────────┐
# │          citer_work_id           │          cited_work_id           │            citer_id            │             work_id              │ citation_weight │ publication_year │    kind     │                id                │                  name                   │ name_ext │ institutions_distinct_count │
# │             varchar              │             varchar              │            varchar             │             varchar              │     double      │      int64       │   varchar   │             varchar              │                 varchar                 │ varchar  │            int64            │
# ├──────────────────────────────────┼──────────────────────────────────┼────────────────────────────────┼──────────────────────────────────┼─────────────────┼──────────────────┼─────────────┼──────────────────────────────────┼─────────────────────────────────────────┼──────────┼─────────────────────────────┤
# │ https://openalex.org/W1000079159 │ https://openalex.org/W2147625786 │ https://openalex.org/I12315562 │ https://openalex.org/W2147625786 │             1.0 │             2013 │ institution │ https://openalex.org/I870124129  │ Mount Royal University                  │ CA       │                           1 │
# │ https://openalex.org/W1000079159 │ https://openalex.org/W2147625786 │ https://openalex.org/I12315562 │ https://openalex.org/W2147625786 │             1.0 │             2013 │ institution │ https://openalex.org/I870124129  │ Mount Royal University                  │ CA       │                           1 │
# │ https://openalex.org/W1000079159 │ https://openalex.org/W2147625786 │ https://openalex.org/I12315562 │ https://openalex.org/W2147625786 │             1.0 │             2013 │ institution │ https://openalex.org/I154425047  │ University of Alberta                   │ CA       │                           1 │
# │ https://openalex.org/W1000079159 │ https://openalex.org/W3123911682 │ https://openalex.org/I12315562 │ https://openalex.org/W3123911682 │             1.0 │             2010 │ institution │ https://openalex.org/I205640436  │ Curtin University                       │ AU       │                           1 │
# │ https://openalex.org/W1000079159 │ https://openalex.org/W3123841633 │ https://openalex.org/I12315562 │ https://openalex.org/W3123841633 │             1.0 │             2013 │ institution │ https://openalex.org/I150744194  │ Waseda University                       │ JP       │                           1 │
# │ https://openalex.org/W1000079159 │ https://openalex.org/W3123841633 │ https://openalex.org/I12315562 │ https://openalex.org/W3123841633 │             1.0 │             2013 │ institution │ https://openalex.org/I150744194  │ Waseda University                       │ JP       │                           1 │
# │ https://openalex.org/W1000079159 │ https://openalex.org/W3123841633 │ https://openalex.org/I12315562 │ https://openalex.org/W3123841633 │             1.0 │             2013 │ institution │ https://openalex.org/I129604602  │ The University of Sydney                │ AU       │                           1 │
# │ https://openalex.org/W1000079159 │ https://openalex.org/W3124690063 │ https://openalex.org/I12315562 │ https://openalex.org/W3124690063 │             1.0 │             2015 │ institution │ https://openalex.org/I12315562   │ Texas Tech University                   │ US       │                           1 │
# │ https://openalex.org/W1000079159 │ https://openalex.org/W3125343438 │ https://openalex.org/I12315562 │ https://openalex.org/W3125343438 │             1.0 │             2014 │ institution │ https://openalex.org/I204722609  │ Queen's University                      │ CA       │                           1 │
# │ https://openalex.org/W1000079159 │ https://openalex.org/W3125343438 │ https://openalex.org/I12315562 │ https://openalex.org/W3125343438 │             1.0 │             2014 │ institution │ https://openalex.org/I97018004   │ Stanford University                     │ US       │                           1 │
# │                ·                 │                ·                 │               ·                │                ·                 │              ·  │               ·  │      ·      │               ·                  │          ·                              │ ·        │                           · │
# │                ·                 │                ·                 │               ·                │                ·                 │              ·  │               ·  │      ·      │               ·                  │          ·                              │ ·        │                           · │
# │                ·                 │                ·                 │               ·                │                ·                 │              ·  │               ·  │      ·      │               ·                  │          ·                              │ ·        │                           · │
# │ https://openalex.org/W1000079159 │ https://openalex.org/W2093319394 │ https://openalex.org/I12315562 │ https://openalex.org/W2093319394 │             1.0 │             2012 │ institution │ https://openalex.org/I75354592   │ Federal Trade Commission                │ US       │                           1 │
# │ https://openalex.org/W1000079159 │ https://openalex.org/W2111980175 │ https://openalex.org/I12315562 │ https://openalex.org/W2111980175 │             1.0 │             2013 │ institution │ https://openalex.org/I931913249  │ Norwegian School of Economics           │ NO       │                           1 │
# │ https://openalex.org/W1000079159 │ https://openalex.org/W2111980175 │ https://openalex.org/I12315562 │ https://openalex.org/W2111980175 │             1.0 │             2013 │ institution │ https://openalex.org/I1279858714 │ Center for Economic and Policy Research │ US       │                           1 │
# │ https://openalex.org/W1000079159 │ https://openalex.org/W2111980175 │ https://openalex.org/I12315562 │ https://openalex.org/W2111980175 │             1.0 │             2013 │ institution │ https://openalex.org/I931913249  │ Norwegian School of Economics           │ NO       │                           1 │
# │ https://openalex.org/W1000079159 │ https://openalex.org/W2111980175 │ https://openalex.org/I12315562 │ https://openalex.org/W2111980175 │             1.0 │             2013 │ institution │ https://openalex.org/I1279858714 │ Center for Economic and Policy Research │ US       │                           1 │
# │ https://openalex.org/W1000079159 │ https://openalex.org/W2125933729 │ https://openalex.org/I12315562 │ https://openalex.org/W2125933729 │             1.0 │             2011 │ institution │ https://openalex.org/I36258959   │ University of California, San Diego     │ US       │                           1 │
# │ https://openalex.org/W1000079159 │ https://openalex.org/W3125343438 │ https://openalex.org/I12315562 │ https://openalex.org/W3125343438 │             1.0 │             2014 │ institution │ https://openalex.org/I97018004   │ Stanford University                     │ US       │                           1 │
# │ https://openalex.org/W1000079159 │ https://openalex.org/W3123841633 │ https://openalex.org/I12315562 │ https://openalex.org/W3123841633 │             1.0 │             2013 │ institution │ https://openalex.org/I129604602  │ The University of Sydney                │ AU       │                           1 │
# │ https://openalex.org/W1000079159 │ https://openalex.org/W2147625786 │ https://openalex.org/I12315562 │ https://openalex.org/W2147625786 │             1.0 │             2013 │ institution │ https://openalex.org/I154425047  │ University of Alberta                   │ CA       │                           1 │
# │ https://openalex.org/W1000079159 │ https://openalex.org/W2141795829 │ https://openalex.org/I12315562 │ https://openalex.org/W2141795829 │             1.0 │             2011 │ institution │ https://openalex.org/I52357470   │ The Ohio State University               │ US       │                           1 │
# ├──────────────────────────────────┴──────────────────────────────────┴────────────────────────────────┴──────────────────────────────────┴─────────────────┴──────────────────┴─────────────┴──────────────────────────────────┴─────────────────────────────────────────┴──────────┴─────────────────────────────┤
# │ 26 rows (20 shown)                                                                                                                                                                                                                                                                                    11 columns │
# └──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
#
# DONE!
