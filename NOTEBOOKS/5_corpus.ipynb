# %% [markdown]
# ### Notebook to look at individual researchers' corpus
#
# - Match Domingo's T/C researchers to OA author_ids
#
#
# - Extract the full corpus of researchers

# %%
import duckdb
import pandas as pd
from pathlib import Path
import diskcache
from collections import defaultdict
from itertools import chain

import numpy as np
from utils.pandas_setup import pandas_setup
pandas_setup()

import contextlib
from unidecode import unidecode
from nameparser import HumanName

import pyalex
from pyalex import Works, Authors, Sources, Institutions, Topics, Publishers, Funders
pyalex.config.email = "Lawrence.Cram@anu.edu.au"
pyalex.config.max_retries = 0
pyalex.config.retry_backoff_factor = 0.1
pyalex.config.retry_http_codes = [429, 500, 503]

MY_DATA_PATH = Path('../DATA/')
MY_DATABASE_FILE = Path(MY_DATA_PATH / 'econ.duckdb')
MY_CACHE_FILE = Path('/home/lc/m/.cache/econommicsbusiness/cache.db')
DATAFILES_PATH = Path('../DATAFILES')

def normalise_name(in_name: str=None) -> list:
    # print(f'{in_name = }')
    in_name = ' '.join([part.strip() for part in unidecode(in_name).split(' ')])
    in_name = in_name.title()
    name = HumanName(in_name)
    
    if name.last == 'Athey':
        name.first = 'Susan.'
    if name.last == 'Deaton':
        name.first = 'Angas.'

    if name.middle == "":
        fullname = f'{name.first} {name.last}'
    else:
        fullname = f'{name.first} {name.middle} {name.last}'

    if fullname == 'David A Hensher':
        fullname = 'David A. Hensher'
    if fullname == 'Ja Robinson':
        fullname = 'James A. Robinson'
    if fullname == "Nicola Fuchs-Schuendeln":
        fullname = "Nicola Fuchs-Schundeln"
    if fullname == "Georg Weizsaecker":
        fullname = "Georg Weizsacker"
    if fullname == "Che Yeon-Koo":
        fullname = "Yeon-Koo Che"
    if fullname == "Dong-Yang Zhang":
        fullname = "Dongyang Zhang"

    # return {'first': name.first, 'middle': name.middle, 'family': name.last, 'fullname': fullname}
    return [name.first, name.middle, name.last, fullname]

# %%
class SetUp:

    def __init__(self):
        self._setup_db()
        return

    def _setup_db(self):
        self.db = duckdb.connect(MY_DATABASE_FILE)
        self.db.sql("ATTACH IF NOT EXISTS ':memory:'")
        self.db.sql(""" SET memory_limit = '56GB';
                        SET threads = 6;
                        SET preserve_insertion_order = false;
                        SET order_by_non_integer_literal=true;
                        SET enable_progress_bar = true;
                        SET temp_directory = '/home/lc/m/.tmp';
                    """)
    
        with contextlib.suppress(Exception):
            self.db.create_function('normalise_name', 
                                        normalise_name, 
                                        return_type=duckdb.duckdb.typing.DuckDBPyType(str), 
                                        exception_handling='return_null',
                                        null_handling='special',
                                        side_effects=True
                                    )
            # self.db.create_function('extract_works', 
            #                             extract_works, 
            #                             return_type=duckdb.duckdb.typing.DuckDBPyType(dict[str, str]), 
            #                         )
        self.db.sql("SHOW ALL TABLES").show()
        return

# %% [markdown]
# #### This cell extracts the endogenous HCRs from works in the Journal Set
#
# - Construct time-series of citations from reference lists
# - Compute the centile for each publication year
# - Filter highly cited papers
# - Group the authors of hte highly cited papers

# %%
class CorpusETL(SetUp):

    def __init__(self):
        super().__init__()
        return

    def citations_per_work(self):
        sql = """ 
        CREATE OR REPLACE TABLE memory.citations_per_work AS
        SELECT c.cited_id,
                count(c.citer_id) AS cited_by_count_endogenous,
                w.cited_by_count AS cited_by_count_total,
                w.publication_year
        FROM
        (SELECT work_id AS citer_id,
                unnest(referenced_works) AS cited_id
            FROM cited
            ) c
        LEFT JOIN works w
        ON c.cited_id = w.work_id
        WHERE w.work_id NOT NULL
        GROUP BY ALL
        ORDER BY publication_year, cited_by_count_endogenous DESC, cited_by_count_total DESC
        """
        self.db.sql(sql)
        return

    def citations_per_work_ranked(self):
        sql = """ 
                CREATE OR REPLACE TABLE memory.citations_per_work_ranked AS
                SELECT cited_id,
                        publication_year,
                        cited_by_count_total,
                        cited_by_count_endogenous,
                        percent_rank(ORDER BY cited_by_count_total) OVER w AS percent_rank_total,
                        percent_rank(ORDER BY cited_by_count_endogenous) OVER w AS percent_rank_endogenous
                FROM memory.citations_per_work
                WINDOW w AS (PARTITION BY publication_year) -- ORDER BY cited_by_count_total, cited_by_count_endogenous) 
                ORDER BY publication_year DESC, percent_rank_total DESC
                """
        self.db.sql(sql)
        return

    def citation_summation(self):
        sql = """ 
                CREATE OR REPLACE TABLE memory.citations AS
                SELECT author_id,
                        author_name,
                        sum(cited_by_count_total) AS citations_total,
                        sum(cited_by_count_endogenous) AS citations_endogenous
                FROM memory.citations_per_work_ranked m
                LEFT JOIN authorships a
                ON m.cited_id = a.work_id
                WHERE author_id NOT NULL
                GROUP BY author_id, author_name
                ORDER BY citations_endogenous DESC
                """
        self.db.sql(sql)
        return

    def hca_summation(self):       

        sql = """ 
                CREATE OR REPLACE TABLE memory.hca_endogenous AS
                SELECT author_id,
                        author_name,
                        count(cited_id) AS hca_endogenous
                FROM memory.citations_per_work_ranked m
                LEFT JOIN authorships a
                ON m.cited_id = a.work_id
                WHERE a.work_id NOT NULL 
                        AND percent_rank_endogenous >= 0.99
                GROUP BY ALL
                ORDER BY hca_endogenous DESC;

                CREATE OR REPLACE TABLE memory.hca_total AS
                SELECT author_id,
                        author_name,
                        count(cited_id) AS hca_total,
                FROM memory.citations_per_work_ranked m
                LEFT JOIN authorships a
                ON m.cited_id = a.work_id
                WHERE a.work_id NOT NULL 
                        AND percent_rank_total >= 0.99
                GROUP BY ALL
                ORDER BY hca_total DESC
                """
        self.db.sql(sql)
        return
    
    def citations_endogenous_all(self):
        sql = """ 
            CREATE OR REPLACE TABLE memory.citations_endogenous_all AS
                SELECT author_id,
                        author_name,
                        citations_total,
                        citations_endogenous,
                        hca_total,
                        hca_endogenous
                FROM memory.citations
                LEFT JOIN
                    (SELECT t.*,
                            e.hca_endogenous
                        FROM memory.hca_total t
                        LEFT JOIN memory.hca_endogenous e
                        USING (author_id)
                    ) sub
                USING (author_id, author_name)
                ORDER BY citations_endogenous DESC
            """
        self.db.sql(sql)
        return

    def author_works_count(self):
        sql = """
            CREATE OR REPLACE TABLE memory.author_works_counts AS
                SELECT au.author_id,
                        au.author_name,
                        a.first,
                        a.middle,
                        a.last,
                        a.fullname,
                        a.orcid,
                        a.display_name_alternatives,
                        count(work_id) AS works_count_endogenous,
                        works_count,
                        cited_by_count,
                        "2yr_mean_citedness",
                        h_index      
                    FROM econ.authorships au
                        LEFT JOIN econ.authors a
                        ON a.author_id = au.author_id
                    GROUP BY ALL
                    ORDER BY works_count_endogenous DESC
            """
        self.db.sql(sql)
        return
    
    def citation_summary(self):

        sql = """ 
            CREATE OR REPLACE TABLE econ.citation_summary AS
                SELECT DISTINCT c.author_id,
                        c.author_name,
                        a.author_name,
                        a.works_count_endogenous,
                        s.citations_total AS citations_total_,
                        c.citations_endogenous,
                        hca_total,
                        hca_endogenous,
                        a.orcid,
                        a.display_name_alternatives,
                        a.works_count AS works_count_total,
                        a.cited_by_count,
                        a."2yr_mean_citedness",
                        a.h_index
                FROM memory.citations c
                    LEFT JOIN memory.citations_endogenous_all s
                    ON c.author_id = s.author_id
                        LEFT JOIN memory.author_works_counts a
                        ON c.author_id = a.author_id
            ORDER BY cited_by_count DESC, h_index DESC
            """
        self.db.sql(sql)
        return
    
    def show_all(self):
        self.db.sql("SELECT * FROM memory.citations_per_work").show()
        self.db.sql("SELECT * FROM memory.citations_per_work_ranked").show()
        self.db.sql("SELECT * FROM memory.citations").show()
        self.db.sql("SELECT * FROM memory.hca_endogenous").show() 
        self.db.sql("SELECT * FROM memory.citations_endogenous_all").show()
        self.db.sql("SELECT * FROM econ.authors").show()  
        self.db.sql("SELECT * FROM econ.citation_summary").show()
        return
    
    def load_citations(self):
        df = self.db.sql("""
                         SELECT * EXCLUDE (author_name_1, display_name_alternatives) FROM econ.citation_summary ORDER BY hca_endogenous DESC, h_index DESC
                         """).df().reset_index(drop=True)
        df.to_excel('../DATA/citation_summary.xlsx', index=False)
        return

# %%
def main():

    cetl = CorpusETL()
    cetl.citations_per_work()
    cetl.citations_per_work_ranked()
    cetl.citation_summation()
    cetl.hca_summation()
    cetl.author_works_count()
    cetl.citations_endogenous_all()
    cetl.citation_summary()
    cetl.show_all()
    cetl.load_citations()
        
    return

# %%
if __name__ == "__main__":
    main()
    print("DONE!")
# Out:
# ┌──────────┬─────────┬───────────────────────────────────────┬──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┬────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┬───────────┐
# │ database │ schema  │                 name                  │                                                                                                                                                                                                 column_names                                                                                                                                                                                                 │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        column_types                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        │ temporary │
# │ varchar  │ varchar │                varchar                │                                                                                                                                                                                                  varchar[]                                                                                                                                                                                                   │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         varchar[]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          │  boolean  │
# ├──────────┼─────────┼───────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────┤
# │ econ     │ main    │ author_works_counts                   │ [author_id, author_name, works_count_endogenous, works_count_total, h_index]                                                                                                                                                                                                                                                                                                                                 │ [VARCHAR, VARCHAR, BIGINT, BIGINT, BIGINT]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 │ false     │
# │ econ     │ main    │ authors                               │ [author_id, orcid, author_name, display_name_alternatives, works_count, cited_by_count, 2yr_mean_citedness, h_index, i10_index, first, middle, last, fullname]                                                                                                                                                                                                                                               │ [VARCHAR, VARCHAR, VARCHAR, VARCHAR[], BIGINT, BIGINT, DOUBLE, BIGINT, BIGINT, VARCHAR, VARCHAR, VARCHAR, VARCHAR]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         │ false     │
# │ econ     │ main    │ authorships                           │ [work_id, author_id, author_name, orcid, institution_id, institution_name, ror, country_code, type]                                                                                                                                                                                                                                                                                                          │ [VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          │ false     │
# │ econ     │ main    │ citation_summary                      │ [author_id, author_name, author_name_1, works_count_endogenous, citations_total_, citations_endogenous, hca_total, hca_endogenous, orcid, display_name_alternatives, works_count_total, cited_by_count, 2yr_mean_citedness, h_index]                                                                                                                                                                         │ [VARCHAR, VARCHAR, VARCHAR, BIGINT, HUGEINT, HUGEINT, BIGINT, BIGINT, VARCHAR, VARCHAR[], BIGINT, BIGINT, DOUBLE, BIGINT]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  │ false     │
# │ econ     │ main    │ cited                                 │ [work_id, referenced_works]                                                                                                                                                                                                                                                                                                                                                                                  │ [VARCHAR, VARCHAR[]]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       │ false     │
# │ econ     │ main    │ domingo_sample                        │ [Research_Profile, ACR, PUB, CIT, HCP, suma, coc, score, Group, first, middle, last, fullname]                                                                                                                                                                                                                                                                                                               │ [VARCHAR, VARCHAR, BIGINT, BIGINT, BIGINT, DOUBLE, DOUBLE, DOUBLE, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            │ false     │
# │ econ     │ main    │ edge_list_combined                    │ [citer_item, cited_item, weights]                                                                                                                                                                                                                                                                                                                                                                            │ [VARCHAR, VARCHAR, DOUBLE]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 │ false     │
# │ econ     │ main    │ hcp_count_endogenous                  │ [index, author_id, author_name, cited_by_count_endogenous, hcp_count, first, middle, family, fullname]                                                                                                                                                                                                                                                                                                       │ [BIGINT, VARCHAR, VARCHAR, BIGINT, BIGINT, VARCHAR, VARCHAR, VARCHAR, VARCHAR]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             │ false     │
# │ econ     │ main    │ institution_citations                 │ [citer_id, cited_id, weights]                                                                                                                                                                                                                                                                                                                                                                                │ [VARCHAR, VARCHAR, DOUBLE]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 │ false     │
# │ econ     │ main    │ pagerank                              │ [pageRank, citer, label, cite_count]                                                                                                                                                                                                                                                                                                                                                                         │ [DOUBLE, VARCHAR, VARCHAR, DOUBLE]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         │ false     │
# │  ·       │  ·      │    ·                                  │                  ·                                                                                                                                                                                                                                                                                                                                                                                           │                 ·                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          │   ·       │
# │  ·       │  ·      │    ·                                  │                  ·                                                                                                                                                                                                                                                                                                                                                                                           │                 ·                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          │   ·       │
# │  ·       │  ·      │    ·                                  │                  ·                                                                                                                                                                                                                                                                                                                                                                                           │                 ·                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          │   ·       │
# │ econ     │ main    │ samples                               │ [Research_Profile, ACR, PUB, CIT, HCP, suma, coc, score, Group, first, last]                                                                                                                                                                                                                                                                                                                                 │ [VARCHAR, VARCHAR, BIGINT, BIGINT, BIGINT, DOUBLE, DOUBLE, DOUBLE, VARCHAR, VARCHAR, VARCHAR]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              │ false     │
# │ econ     │ main    │ source_citations                      │ [citer_id, cited_id, weights]                                                                                                                                                                                                                                                                                                                                                                                │ [VARCHAR, VARCHAR, BIGINT]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 │ false     │
# │ econ     │ main    │ sources_oa_incites                    │ [id, issn_l, issn, display_name, host_organization, host_organization_name, host_organization_lineage, works_count, cited_by_count, summary_stats, is_oa, is_in_doaj, is_indexed_in_scopus, is_core, ids, homepage_url, apc_prices, apc_usd, country_code, societies, alternate_titles, abbreviated_title, type, topics, topic_share, x_concepts, counts_by_year, works_api_url, updated_date, created_date] │ [VARCHAR, VARCHAR, VARCHAR[], VARCHAR, VARCHAR, VARCHAR, VARCHAR[], BIGINT, BIGINT, STRUCT("2yr_mean_citedness" DOUBLE, h_index INTEGER, i10_index INTEGER), BOOLEAN, BOOLEAN, BOOLEAN, BOOLEAN, VARCHAR, VARCHAR, STRUCT(price INTEGER, currency VARCHAR)[], DOUBLE, VARCHAR, STRUCT(url VARCHAR, organization VARCHAR)[], VARCHAR[], VARCHAR, VARCHAR, STRUCT(id VARCHAR, display_name VARCHAR, count INTEGER, subfield STRUCT(id VARCHAR, display_name VARCHAR), field STRUCT(id VARCHAR, display_name VARCHAR), "domain" STRUCT(id VARCHAR, display_name VARCHAR))[], STRUCT(id VARCHAR, display_name VARCHAR, "value" DOUBLE, subfield STRUCT(id VARCHAR, display_name VARCHAR), field STRUCT(id VARCHAR, display_name VARCHAR), "domain" STRUCT(id VARCHAR, display_name VARCHAR))[], STRUCT(id VARCHAR, wikidata VARCHAR, display_name VARCHAR, "level" INTEGER, score DOUBLE)[], STRUCT("year" INTEGER, works_count INTEGER, cited_by_count INTEGER)[], VARCHAR, VARCHAR, VARCHAR] │ false     │
# │ econ     │ main    │ weighted_citation_counts              │ [weighted_citations, citations, author_id, author_name]                                                                                                                                                                                                                                                                                                                                                      │ [DOUBLE, BIGINT, VARCHAR, VARCHAR]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         │ false     │
# │ econ     │ main    │ weighted_citation_counts_institutions │ [weighted_citations, citations, author_id, author_name]                                                                                                                                                                                                                                                                                                                                                      │ [DOUBLE, BIGINT, VARCHAR, VARCHAR]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         │ false     │
# │ econ     │ main    │ weighted_citation_counts_journals     │ [weighted_citations, citations, author_id, author_name]                                                                                                                                                                                                                                                                                                                                                      │ [DOUBLE, BIGINT, VARCHAR, VARCHAR]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         │ false     │
# │ econ     │ main    │ weighted_citations_both               │ [author_id, citer_count, citer_count_weighted]                                                                                                                                                                                                                                                                                                                                                               │ [VARCHAR, BIGINT, DOUBLE]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  │ false     │
# │ econ     │ main    │ weighted_citations_institutions       │ [author_id, citer_count, citer_count_weighted]                                                                                                                                                                                                                                                                                                                                                               │ [VARCHAR, BIGINT, DOUBLE]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  │ false     │
# │ econ     │ main    │ weighted_citations_sources            │ [author_id, citer_count, citer_count_weighted]                                                                                                                                                                                                                                                                                                                                                               │ [VARCHAR, BIGINT, DOUBLE]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  │ false     │
# │ econ     │ main    │ works                                 │ [work_id, doi, title, display_name, publication_year, type, countries_distinct_count, institutions_distinct_count, fwci, has_fulltext, cited_by_count, is_retracted, is_paratext, referenced_works_count, cited_by_api_url, updated_date, created_date, is_authors_truncated, volume, issue, first_page, last_page, source_id, source_name, host_id, host_name]                                              │ [VARCHAR, VARCHAR, VARCHAR, VARCHAR, BIGINT, VARCHAR, BIGINT, BIGINT, DOUBLE, BOOLEAN, BIGINT, BOOLEAN, BOOLEAN, BIGINT, VARCHAR, VARCHAR, VARCHAR, BOOLEAN, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       │ false     │
# ├──────────┴─────────┴───────────────────────────────────────┴──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┴────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┴───────────┤
# │ 27 rows (20 shown)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       6 columns │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
#
# ┌──────────────────────────────────┬───────────────────────────┬──────────────────────┬──────────────────┐
# │             cited_id             │ cited_by_count_endogenous │ cited_by_count_total │ publication_year │
# │             varchar              │           int64           │        int64         │      int64       │
# ├──────────────────────────────────┼───────────────────────────┼──────────────────────┼──────────────────┤
# │ https://openalex.org/W3125367243 │                      1339 │                 4047 │             2010 │
# │ https://openalex.org/W3121239293 │                       980 │                 3953 │             2010 │
# │ https://openalex.org/W2115657206 │                       784 │                 2291 │             2010 │
# │ https://openalex.org/W2148534039 │                       695 │                 2070 │             2010 │
# │ https://openalex.org/W4298304389 │                       691 │                 4598 │             2010 │
# │ https://openalex.org/W1983291248 │                       680 │                 1728 │             2010 │
# │ https://openalex.org/W2140286179 │                       660 │                 1817 │             2010 │
# │ https://openalex.org/W2005029869 │                       631 │                 2047 │             2010 │
# │ https://openalex.org/W3124635110 │                       595 │                 2263 │             2010 │
# │ https://openalex.org/W3122967851 │                       593 │                 1483 │             2010 │
# │                ·                 │                         · │                    · │               ·  │
# │                ·                 │                         · │                    · │               ·  │
# │                ·                 │                         · │                    · │               ·  │
# │ https://openalex.org/W4288040466 │                         4 │                   11 │             2022 │
# │ https://openalex.org/W4291002615 │                         4 │                   11 │             2022 │
# │ https://openalex.org/W4313199126 │                         4 │                   11 │             2022 │
# │ https://openalex.org/W3113112850 │                         4 │                   11 │             2022 │
# │ https://openalex.org/W4293377790 │                         4 │                   10 │             2022 │
# │ https://openalex.org/W4281483591 │                         4 │                   10 │             2022 │
# │ https://openalex.org/W4214815607 │                         4 │                   10 │             2022 │
# │ https://openalex.org/W4292086365 │                         4 │                   10 │             2022 │
# │ https://openalex.org/W4281874641 │                         4 │                   10 │             2022 │
# │ https://openalex.org/W4220955144 │                         4 │                   10 │             2022 │
# ├──────────────────────────────────┴───────────────────────────┴──────────────────────┴──────────────────┤
# │ ? rows (>9999 rows, 20 shown)                                                                4 columns │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────┘
#
# ┌──────────────────────────────────┬──────────────────┬──────────────────────┬───────────────────────────┬─────────────────────┬─────────────────────────┐
# │             cited_id             │ publication_year │ cited_by_count_total │ cited_by_count_endogenous │ percent_rank_total  │ percent_rank_endogenous │
# │             varchar              │      int64       │        int64         │           int64           │       double        │         double          │
# ├──────────────────────────────────┼──────────────────┼──────────────────────┼───────────────────────────┼─────────────────────┼─────────────────────────┤
# │ https://openalex.org/W2252419224 │             2012 │                   15 │                         1 │ 0.35421213443910954 │                     0.0 │
# │ https://openalex.org/W1981237658 │             2012 │                   15 │                         1 │ 0.35421213443910954 │                     0.0 │
# │ https://openalex.org/W2016166018 │             2012 │                   15 │                         1 │ 0.35421213443910954 │                     0.0 │
# │ https://openalex.org/W2167858708 │             2012 │                   15 │                         1 │ 0.35421213443910954 │                     0.0 │
# │ https://openalex.org/W2321666545 │             2012 │                   15 │                         1 │ 0.35421213443910954 │                     0.0 │
# │ https://openalex.org/W2132702971 │             2012 │                   15 │                         1 │ 0.35421213443910954 │                     0.0 │
# │ https://openalex.org/W1970502933 │             2012 │                   15 │                         1 │ 0.35421213443910954 │                     0.0 │
# ...
# │ https://openalex.org/A5079045310 │ NULL                                  │ Ágnes Borgulya           │ [Agnes Borgulya, Ágnes Borgulya]                                                                       │          18 │             38 │                2.5 │       4 │         1 │ Agnes     │         │ Borgulya    │ Agnes Borgulya           │
# │ https://openalex.org/A5079060545 │ NULL                                  │ Kineung Choo             │ [Kineung Choo]                                                                                         │          17 │            482 │                0.0 │       4 │         4 │ Kineung   │         │ Choo        │ Kineung Choo             │
# ├──────────────────────────────────┴───────────────────────────────────────┴──────────────────────────┴────────────────────────────────────────────────────────────────────────────────────────────────────────┴─────────────┴────────────────┴────────────────────┴─────────┴───────────┴───────────┴─────────┴─────────────┴──────────────────────────┤
# │ ? rows (>9999 rows, 20 shown)                                                                                                                                                                                                                                                                                                              13 columns │
# └───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
#
# ┌──────────────────────────────────┬──────────────────────┬──────────────────────┬────────────────────────┬──────────────────┬──────────────────────┬───────────┬────────────────┬───────────────────────────────────────┬───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┬───────────────────┬────────────────┬─────────────────────┬─────────┐
# │            author_id             │     author_name      │    author_name_1     │ works_count_endogenous │ citations_total_ │ citations_endogenous │ hca_total │ hca_endogenous │                 orcid                 │                                                                             display_name_alternatives                                                                             │ works_count_total │ cited_by_count │ 2yr_mean_citedness  │ h_index │
# │             varchar              │       varchar        │       varchar        │         int64          │      int128      │        int128        │   int64   │     int64      │                varchar                │                                                                                     varchar[]                                                                                     │       int64       │     int64      │       double        │  int64  │
# ├──────────────────────────────────┼──────────────────────┼──────────────────────┼────────────────────────┼──────────────────┼──────────────────────┼───────────┼────────────────┼───────────────────────────────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────────────┼────────────────┼─────────────────────┼─────────┤
# │ https://openalex.org/A5100959380 │ Huang Zhi-Bin        │ Huang Zhi-Bin        │                      4 │               57 │                   23 │      NULL │           NULL │ NULL                                  │ [Z. Huang, Zhibin Huang, Zhi‐Bin Huang, Huang Zhi‐bin, Huang Zhibin]                                                                                                              │                72 │            255 │                 3.5 │      10 │
# │ https://openalex.org/A5035016214 │ Vinicius Costa       │ Vinicius Costa       │                      1 │               26 │                    1 │      NULL │           NULL │ https://orcid.org/0000-0001-8717-8538 │ [Vinicius Braga Ferreira da Costa, Vinícius B. F. Da Costa, Vinícius Braga Ferreira da Costa, Vinicius Costa, Vinicius B. F. Costa, V.B.F. Costa]                                 │                43 │            255 │   2.933333333333333 │      10 │
# │ https://openalex.org/A5039819927 │ Anna Kopiczko        │ Anna Kopiczko        │                      1 │               24 │                    1 │      NULL │           NULL │ https://orcid.org/0000-0002-1222-113X │ [A. Kopiczko, Anna Kopiczko]                                                                                                                                                      │                46 │            255 │  2.8333333333333335 │      10 │
# │ https://openalex.org/A5047793713 │ Xinyue Ding          │ Xinyue Ding          │                      1 │                1 │                    1 │      NULL │           NULL │ https://orcid.org/0000-0003-1375-9473 │ [Xinyue Ding, Xin‐Yue Ding]                                                                                                                                                       │                35 │            255 │   4.166666666666667 │      10 │
# │ https://openalex.org/A5041278299 │ Boris Stemmer        │ Boris Stemmer        │                      1 │               32 │                    4 │      NULL │           NULL │ https://orcid.org/0000-0002-8872-9693 │ [B. Stemmer, Boris Stemmer]                                                                                                                                                       │                37 │            255 │                 7.5 │       9 │
# │ https://openalex.org/A5069416611 │ E. Chuke Nwude       │ E. Chuke Nwude       │                      1 │                7 │                    1 │      NULL │           NULL │ https://orcid.org/0000-0001-5629-7614 │ [E.C Nwude, Emmanuel Chuke Nwude, E. Chuke Nwude E. Chuke Nwude, E. Chuke Nwude]                                                                                                  │                74 │            255 │                 2.0 │       9 │
# │ https://openalex.org/A5019233878 │ Mohamad Dian Revindo │ Mohamad Dian Revindo │                      2 │                5 │                    3 │      NULL │           NULL │ https://orcid.org/0000-0002-3364-2806 │ [Mohamad Revindo, Mohamad D. Revindo, Mohamad Dian Revindo]                                                                                                                       │                42 │            255 │ 0.42857142857142855 │       9 │
# │ https://openalex.org/A5040208035 │ Guy Jakeman          │ Guy Jakeman          │                      1 │                8 │                    3 │      NULL │           NULL │ NULL                                  │ [G. Jakeman, G.N. Jakeman, Guy Jakeman]                                                                                                                                           │                21 │            255 │                 0.0 │       9 │
# │ https://openalex.org/A5013097955 │ Huidi Li             │ Huidi Li             │                      1 │                8 │                    1 │      NULL │           NULL │ https://orcid.org/0000-0001-8380-5151 │ [Hui‐Di Li, Huidi Li, LI Hui‐di]                                                                                                                                                  │                30 │            255 │                 2.0 │       9 │
# │ https://openalex.org/A5025679702 │ Elzbieta Antczak     │ Elzbieta Antczak     │                     10 │               15 │                    6 │      NULL │           NULL │ https://orcid.org/0000-0002-9695-6300 │ [Elzbieta Antczak, E Antczak, Elźbieta Antczak, Elżbieta Antczak]                                                                                                                 │                74 │            255 │               1.125 │       9 │
# │                ·                 │      ·               │      ·               │                      · │                · │                    · │        ·  │             ·  │                   ·                   │                              ·                                                                                                                                                    │                 · │             ·  │                 ·   │       · │
# │                ·                 │      ·               │      ·               │                      · │                · │                    · │        ·  │             ·  │                   ·                   │                              ·                                                                                                                                                    │                 · │             ·  │                 ·   │       · │
# │                ·                 │      ·               │      ·               │                      · │                · │                    · │        ·  │             ·  │                   ·                   │                              ·                                                                                                                                                    │                 · │             ·  │                 ·   │       · │
# │ https://openalex.org/A5030998554 │ Andre Blais          │ Andre Blais          │                      7 │              134 │                   40 │      NULL │           NULL │ https://orcid.org/0000-0003-4292-110X │ [André Guntermann Blais, A. Blais, Andre Blais, André Blais]                                                                                                                      │               561 │          18112 │  0.8888888888888888 │      69 │
# │ https://openalex.org/A5001057120 │ Weiming Zhang        │ Weiming Zhang        │                      1 │               20 │                    2 │      NULL │           NULL │ https://orcid.org/0000-0001-5263-0512 │ [Zhang Weiming, Weiming Zhang, W ZHANG, Zhang Wei‐ming, Wenshen Zhang, Wei‐Ming Zhang, Z QUANXING, Zhang Quan‐xing, W.M. Zhang, Zhang Quanxing]                                   │               463 │          18112 │    8.91891891891892 │      64 │
# │ https://openalex.org/A5072718029 │ Gary Sacks           │ Gary Sacks           │                      5 │               46 │                    3 │      NULL │           NULL │ https://orcid.org/0000-0001-9736-1539 │ [G. Sacks, Gary Sacks]                                                                                                                                                            │               302 │          18112 │    3.56140350877193 │      54 │
# │ https://openalex.org/A5019704910 │ Jeong-Bon Kim        │ Jeong-Bon Kim        │                     15 │             3557 │                  606 │         2 │              2 │ https://orcid.org/0000-0003-0709-4831 │ [J. Kim, Kim Jeong‐Bon, Jeong‐Bon Kim, Jeong Bon Kim]                                                                                                                             │               345 │          18109 │   2.323529411764706 │      61 │
# │ https://openalex.org/A5077462483 │ Ulf Dahlstrom        │ Ulf Dahlstrom        │                      1 │               29 │                    1 │      NULL │           NULL │ https://orcid.org/0000-0001-6353-8041 │ [U. Dahlström, U. Dahlström⁎, Ulf Dahlström, U L F Dahlstrom, U. Dahlstrom, Ulf Dahlstrom]                                                                                        │               433 │          18106 │   6.980392156862745 │      68 │
# │ https://openalex.org/A5038335245 │ Susanne M. Benseler  │ Susanne M. Benseler  │                      2 │               14 │                    2 │      NULL │           NULL │ https://orcid.org/0000-0001-5756-3638 │ [S. Benseler, Susa M. Benseler, Susanne M. Benseler, Susanne. Benseler, Susan Benseler, Susan M Benseler, S. M. Benseler, Susa Benseler, Suse Benseler]                           │               329 │          18093 │   2.967741935483871 │      61 │
# │ https://openalex.org/A5009534806 │ Serge Perrot         │ Serge Perrot         │                      1 │               87 │                    2 │      NULL │           NULL │ https://orcid.org/0000-0002-0509-1592 │ [S. Perrot, Serge. Perrot]                                                                                                                                                        │               501 │          18093 │  1.8936170212765957 │      60 │
# │ https://openalex.org/A5027387690 │ David Grant          │ David Grant          │                      3 │               72 │                    3 │      NULL │           NULL │ https://orcid.org/0000-0002-5602-5640 │ [DavidB. Grant, John Grant, David B. Grant, John F. Grant, D. B. Grant, D. B Grant, David. Grant, John Fernie David B. Grant, D. Grant, David Bruce Grant, J. Grant, J. F. Grant] │               623 │          18087 │  0.9090909090909091 │      68 │
# │ https://openalex.org/A5016033472 │ Reinhard Madlener    │ Reinhard Madlener    │                     55 │             2736 │                  475 │      NULL │           NULL │ https://orcid.org/0000-0003-1514-6486 │ [R. Madlener, Reinhard Madlener, Madlener Reinhard]                                                                                                                               │               687 │          18082 │                3.25 │      78 │
# │ https://openalex.org/A5058807462 │ Kelly A. Gebo        │ Kelly A. Gebo        │                      1 │                2 │                    2 │      NULL │           NULL │ https://orcid.org/0000-0003-4010-398X │ [K. Gebo, K. A. Gebo, K. A Gebo, Kelly Gebo, Kelly A. Gebo]                                                                                                                       │               339 │          18082 │             7.53125 │      70 │
# ├──────────────────────────────────┴──────────────────────┴──────────────────────┴────────────────────────┴──────────────────┴──────────────────────┴───────────┴────────────────┴───────────────────────────────────────┴───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┴───────────────────┴────────────────┴─────────────────────┴─────────┤
# │ ? rows (>9999 rows, 20 shown)                                                                                                                                                                                                                                                                                                                                                                                                                                        14 columns │
# └─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
#
# DONE!
