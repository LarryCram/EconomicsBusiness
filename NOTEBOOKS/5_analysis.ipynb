# %% [markdown]
# ### This ANALYSYS notebook
#
# -

# %%
import duckdb
import pandas as pd
from pathlib import Path
import diskcache
from itertools import chain

import igraph as ig
import cairo
import seaborn as sns
import matplotlib.pyplot as plt

from utils.pandas_setup import pandas_setup
pandas_setup()
from IPython.display import display

import pyalex
from pyalex import Works, Authors, Sources, Institutions, Topics, Publishers, Funders
pyalex.config.email = "Lawrence.Cram@anu.edu.au"
pyalex.config.max_retries = 0
pyalex.config.retry_backoff_factor = 0.1
pyalex.config.retry_http_codes = [429, 500, 503]

MY_DATA_PATH = Path('../DATA/')
MY_DATABASE_FILE = Path(MY_DATA_PATH / 'econ.duckdb')
MY_CACHE_FILE = Path('/home/lc/m/.cache/economicsbusiness/cache.db')
DATAFILES_PATH = Path('../DATAFILES')

# %%
class SetUp:

    def __init__(self):
        self._setup_db()
        self._setup_cache()
        return
    
    def _setup_db(self):
        self.db = duckdb.connect(MY_DATABASE_FILE)
        self.db.sql(""" SET memory_limit = '56GB';
                        SET threads = 6;
                        SET preserve_insertion_order = false;
                        SET order_by_non_integer_literal=true;
                        SET enable_progress_bar = true;
                        SET temp_directory = '/home/lc/m/.tmp';
                    """)
        self.db.sql("SHOW ALL TABLES").show()
        return
    
    def _setup_cache(self):
        self.cache = diskcache.Cache(MY_CACHE_FILE, size_limit=16_000_000_000)
        print(f'{self.cache.check() = }')
        print(f'{self.cache.volume() = }')
        return
    
    def name_of_global_obj(self, obj=None):
        for objname, oid in globals().items():
            if oid is obj:
                return objname

# %%
class TimeSeries(SetUp):

    def __init__(self):
        super().__init__()
        return
    
    def basic_time_series(self):
        print('basic time series')
        sql = """
            SELECT publication_year AS 'publication_year', 
                    count(work_id) AS 'works_count',
                    sum(cited_by_count)/count(work_id) AS 'mean_cites',
                    sum(referenced_works_count)/count(work_id) AS 'mean_references'
                FROM workssudo apt-get install libcairo2-dev
                GROUP BY publication_year
                ORDER BY publication_year
            """
        df = self.db.sql(sql).df()
        print(f'{df.shape = }\n{df.head()}')
        self.plot_basic_time_series(df=df)
        return
    
    def count_types(self):
        t = self.db.sql("""
                            SELECT type, count(work_id) AS count 
                                FROM works WHERE contains('article review preprint letter', type) = true 
                                GROUP BY type 
                                ORDER BY count DESC""").df()
        print(f'{t.shape = }\n{t.head(9)}')
        return
    
    def plot_basic_time_series(self, df=None):
        fig, ax = plt.subplots(1, 1)
        sns.lineplot(df, x='publication_year', y='mean_references', ax=ax)
        ax.set_ylim((0, 50))
        ax.set_xlim((2010, 2025))
        plt.show()

        fig, ax = plt.subplots(1, 1)
        sns.lineplot(df, x='publication_year', y='works_count', ax=ax)
        ax.set_ylim((0, 50000))
        ax.set_xlim((2010, 2025))
        plt.show()
        return

    def authorship_time_series(self):
        sql = """
                SELECT DISTINCT author_id, 
                                author_name AS 'author name',
                                works_count,
                                cites_count,
                                cites_count//works_count AS cites_per_work,
                                start_year,
                                end_year,
                                -- publication_years,
                                works_count//(1+end_year-start_year) AS 'pub_rate_per_year'
                    FROM
                        (SELECT author_id,
                                author_name,
                                count(DISTINCT work_id) AS works_count,
                                sum(cited_by_count) AS cites_count,
                                min(publication_year) AS start_year,
                                max(publication_year) AS end_year,
                                -- list(publication_year) AS publication_years
                            FROM authorships a
                                LEFT JOIN works w
                                USING (work_id)
                                WHERE contains('article review preprint letter', w.type) = true 
                                    -- AND w.title != 'Frontmatter'
                                GROUP BY author_id, author_name
                        )
                    ORDER BY works_count DESC --cites_per_work DESC -- pub_rate_per_year DESC --works_count DESC
            """
        df = self.db.sql(sql).df()
        df.to_csv('../DATA/authorship_time_series.csv')
        return
    
    def journal_edge_list(self):
        # SQL code to assemble the source-source edge list with the count of work-work citations as weights
        sql = """
        CREATE OR REPLACE TABLE econ.source_citations AS
        SELECT --sub.work_id,
                --sub.cited_id,
                sub.source_id AS citer_id,
                ww.source_id AS cited_id,
                count(ww.work_id) AS weights,
        FROM
            (SELECT w.work_id,
                    w.source_id,
                    w.cited_by_count,
                    unnest(c.referenced_works) AS cited_id
            FROM works w
            LEFT JOIN cited c
            USING (work_id)
            WHERE w.source_id NOT NULL) sub 
            
        LEFT JOIN works ww
            ON ww.work_id = sub.cited_id
            WHERE ww.source_id NOT NULL
        GROUP BY sub.source_id, ww.source_id
        ORDER BY weights DESC
        """
        self.db.sql(sql)
        return

    def journal_citations(self):
        df = self.db.sql("SELECT * FROM econ.source_citations").df()
        df = df[df.citer_id != df.cited_id]
        df = df[df.weights > 1000]
        print(f'{df.shape = }\n{df.head()}')
        g = ig.Graph.DataFrame(df, directed=True, use_vids=False)
        layout = g.layout(layout="circle")
        fig, ax = plt.subplots()
        ig.plot(g, bbox=(0, 0, 100, 100), target=ax, layout=layout, vertex_size=2, edge_width=1, edge_arrow_width=1)
        plt.show()
        return

# %%
class Distributions(SetUp):

    def __init__(self):
        super().__init__()
        return
    
    def source_works(self):
        df = self.db.sql("SELECT * FROM works").df()[['work_id', 'source_id']]
        print(f'{df.shape = } {df.source_id.nunique() = }\n{df.head()}')
        source_counts = df.groupby('source_id').work_id.count().reset_index().\
            rename(columns={'work_id': 'work_count'}).sort_values(['work_count'], ascending=[True]).reset_index(drop=True).reset_index()
        source_counts = source_counts[source_counts.work_count > 100]
        print(f'{source_counts.shape = }\n{source_counts.head()}\n{source_counts.tail()}')
        fig, ax = plt.subplots(1, 1)
        sns.scatterplot(source_counts, x='index', y='work_count', color='black', size=1)
        ax.set_xlim(1, 1000)
        ax.set_ylim(10, 10000)
        ax.set_yscale('log')
        ax.set_xscale('log')
        ax.set_title('Cumulative count of sources')
        plt.show()        
        return
    
    def institutions_works(self):
        df = self.db.sql("SELECT DISTINCT work_id, institution_id FROM authorships").df()[['work_id', 'institution_id']]
        print(f'{df.shape = } {df.institution_id.nunique() = }\n{df.head()}')
        institution_counts = df.groupby('institution_id').work_id.count().reset_index().\
            rename(columns={'work_id': 'work_count'}).sort_values(['work_count'], ascending=[True]).reset_index(drop=True).reset_index()
        # institution_counts = institution_counts[institution_counts.work_count > 100]
        print(f'{institution_counts.shape = }\n{institution_counts.head()}\n{institution_counts.tail()}')
        fig, ax = plt.subplots(1, 1)
        sns.scatterplot(institution_counts, x='index', y='work_count', color='black', size=1)
        ax.set_xticks([])
        ax.set_xlim(10000, 30000)
        ax.set_ylim(1, 10000)
        ax.set_yscale('log')
        ax.set_xscale('log')
        ax.set_title('Cumulative count of institutions')
        plt.show()        
        return

# %%
class PagerankCitations(SetUp):

    def __init__(self):
        super().__init__()
        return
    
    def pagerank_citations(self):
        self.db.sql("SELECT * FROM source_citations ORDER BY weights DESC").show()
        hold = []
        for panel in ['sources', 'institutions', 'both']:
            sql = f"""
                WITH 
                    source_citations_cte AS
                        (SELECT 'Sources' AS kind, cited_id, sum(weights) AS citation_count FROM source_citations GROUP BY cited_id),
                    institution_citations_cte AS
                        (SELECT 'Institutions' AS kind, cited_id, sum(weights) AS citation_count FROM institution_citations GROUP BY cited_id),
                    citations_cte AS
                        (SELECT * FROM source_citations_cte
                            UNION
                        SELECT * FROM institution_citations_cte)
                SELECT * FROM citations_cte c
                LEFT JOIN pagerank_{panel} p
                ON p.citer = c.cited_id
                WHERE pageRank NOT NULL AND kind NOT NULL
                """
            temp = self.db.sql(sql).df()
            temp['panel'] = panel.title()
            print(f'{temp.shape = }\n{temp.head()}')
            hold.append(temp)
        df = pd.concat(hold, axis=0).sort_values('citation_count', ascending=False)
        g = sns.relplot(df, x='pageRank', y='citation_count', col='panel', hue='kind', kind='scatter')
        for ax in g.axes.flat:
            ax.set_xscale('log')
            ax.set_yscale('log')
        plt.show() 
        self._replot(df=df)
        return
    
    def _replot(self, df=None):

        hold = []
        for kind in ['Sources', 'Institutions']:
            m1 = [k == kind and p == k for k, p in zip(df.kind, df.panel)]
            m2 = [k == kind and p == 'Both' for k, p in zip(df.kind, df.panel)]
            p1 = pd.DataFrame(list(zip(1000.0*df[m1].pageRank/df[m1].out_degree, 1000.0*df[m2].pageRank/df[m2].out_degree, df[m1].label)), columns=['Alone', 'Both', 'Name'])
            p1['panel'] = kind
            hold.append(p1)
        df = pd.concat(hold, axis=0).sort_values('Both', ascending=False).reset_index(drop=True)
        print(df.head())
        print(df.groupby(['panel']).count())
        g = sns.scatterplot(df, x='Alone', y='Both', hue='panel', )
        g.set_xscale('log')
        g.set_yscale('log')
        for i, row in df.iterrows():
            if i in [0, 3, 10, 30, 100, 300, 552, 552+1, 552+3, 552+10, 552+30, 552+100, 552+300]:  #row['label'] in ['A', 'C', 'E']:  Example: label points A, C, and E
                if row['panel'] == 'Sources':
                    plt.text(row['Alone'], row['Both'], row['Name'], fontsize=8, ha='left', va='center')
                else:
                    plt.text(row['Alone'], row['Both'], row['Name'], fontsize=8, ha='right', va='center')
        g.set_title("Comparision of pagerank values")
        plt.show()

# %%
def main():

    # ts = TimeSeries()
    # ts.basic_time_series()
    # ts.authorship_time_series()
    # ts.count_types()
    # ts.journal_edge_list()
    # ts.journal_citations()

    # d = Distributions()
    # d.source_works()
    pc= PagerankCitations()
    pc.pagerank_citations()
    # d.institutions_works()

    pc= PagerankCitations()
    pc.pagerank_citations()

# %%
if __name__ == "__main__":
    main()
    print("DONE!")
# Out:
# ┌──────────┬─────────┬─────────────────────────────────┬──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┬────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┬───────────┐
# │ database │ schema  │              name               │                                                                                                                                                                                                 column_names                                                                                                                                                                                                 │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        column_types                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        │ temporary │
# │ varchar  │ varchar │             varchar             │                                                                                                                                                                                                  varchar[]                                                                                                                                                                                                   │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         varchar[]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          │  boolean  │
# ├──────────┼─────────┼─────────────────────────────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼───────────┤
# │ econ     │ main    │ author_works_counts             │ [author_id, author_name, works_count_endogenous, works_count_total, h_index]                                                                                                                                                                                                                                                                                                                                 │ [VARCHAR, VARCHAR, BIGINT, BIGINT, BIGINT]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 │ false     │
# │ econ     │ main    │ authors                         │ [author_id, orcid, author_name, display_name_alternatives, works_count, cited_by_count, 2yr_mean_citedness, h_index, i10_index, first, middle, last, fullname]                                                                                                                                                                                                                                               │ [VARCHAR, VARCHAR, VARCHAR, VARCHAR[], BIGINT, BIGINT, DOUBLE, BIGINT, BIGINT, VARCHAR, VARCHAR, VARCHAR, VARCHAR]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         │ false     │
# │ econ     │ main    │ authorships                     │ [work_id, author_id, author_name, orcid, institution_id, institution_name, ror, country_code, type]                                                                                                                                                                                                                                                                                                          │ [VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          │ false     │
# │ econ     │ main    │ citation_summary                │ [author_id, author_name, author_name_1, works_count_endogenous, citations_total_, citations_endogenous, hca_total, hca_endogenous, orcid, display_name_alternatives, works_count_total, cited_by_count, 2yr_mean_citedness, h_index]                                                                                                                                                                         │ [VARCHAR, VARCHAR, VARCHAR, BIGINT, HUGEINT, HUGEINT, BIGINT, BIGINT, VARCHAR, VARCHAR[], BIGINT, BIGINT, DOUBLE, BIGINT]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  │ false     │
# │ econ     │ main    │ cited                           │ [work_id, referenced_works]                                                                                                                                                                                                                                                                                                                                                                                  │ [VARCHAR, VARCHAR[]]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       │ false     │
# │ econ     │ main    │ domingo_sample                  │ [Research_Profile, ACR, PUB, CIT, HCP, suma, coc, score, Group, first, middle, last, fullname]                                                                                                                                                                                                                                                                                                               │ [VARCHAR, VARCHAR, BIGINT, BIGINT, BIGINT, DOUBLE, DOUBLE, DOUBLE, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            │ false     │
# │ econ     │ main    │ edge_list_combined              │ [citer_item, cited_item, weights]                                                                                                                                                                                                                                                                                                                                                                            │ [VARCHAR, VARCHAR, DOUBLE]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 │ false     │
# │ econ     │ main    │ hcp_count_endogenous            │ [index, author_id, author_name, cited_by_count_endogenous, hcp_count, first, middle, family, fullname]                                                                                                                                                                                                                                                                                                       │ [BIGINT, VARCHAR, VARCHAR, BIGINT, BIGINT, VARCHAR, VARCHAR, VARCHAR, VARCHAR]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             │ false     │
# │ econ     │ main    │ institution_citations           │ [citer_id, cited_id, weights]                                                                                                                                                                                                                                                                                                                                                                                │ [VARCHAR, VARCHAR, DOUBLE]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 │ false     │
# │ econ     │ main    │ pagerank_both                   │ [pageRank, citer, label, in_degree, out_degree]                                                                                                                                                                                                                                                                                                                                                              │ [DOUBLE, VARCHAR, VARCHAR, DOUBLE, DOUBLE]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 │ false     │
# │ econ     │ main    │ pagerank_institutions           │ [pageRank, citer, label, in_degree, out_degree]                                                                                                                                                                                                                                                                                                                                                              │ [DOUBLE, VARCHAR, VARCHAR, DOUBLE, DOUBLE]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 │ false     │
# │ econ     │ main    │ pagerank_sources                │ [pageRank, citer, label, in_degree, out_degree]                                                                                                                                                                                                                                                                                                                                                              │ [DOUBLE, VARCHAR, VARCHAR, DOUBLE, DOUBLE]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 │ false     │
# │ econ     │ main    │ sample_matched                  │ [Research_Profile, orcid, author_id, first, last, fullname, ACR, PUB, CIT, HCP, suma, coc, score, Group, works_count_endogenous, citations_endogenous, hca_endogenous, works_count_total, cited_by_count, hca_total, 2yr_mean_citedness, h_index, citations_total_oa]                                                                                                                                        │ [VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR, BIGINT, BIGINT, BIGINT, DOUBLE, DOUBLE, DOUBLE, VARCHAR, BIGINT, HUGEINT, BIGINT, BIGINT, BIGINT, BIGINT, DOUBLE, BIGINT, HUGEINT]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         │ false     │
# │ econ     │ main    │ sample_names                    │ [Research_Profile, author_id, author_name, Group, CIT, PUB, HCP, last, works_count]                                                                                                                                                                                                                                                                                                                          │ [VARCHAR, VARCHAR, VARCHAR, VARCHAR, BIGINT, BIGINT, BIGINT, VARCHAR, BIGINT]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              │ false     │
# │ econ     │ main    │ samples                         │ [Research_Profile, ACR, PUB, CIT, HCP, suma, coc, score, Group, first, last]                                                                                                                                                                                                                                                                                                                                 │ [VARCHAR, VARCHAR, BIGINT, BIGINT, BIGINT, DOUBLE, DOUBLE, DOUBLE, VARCHAR, VARCHAR, VARCHAR]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              │ false     │
# │ econ     │ main    │ source_citations                │ [citer_id, cited_id, weights]                                                                                                                                                                                                                                                                                                                                                                                │ [VARCHAR, VARCHAR, BIGINT]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 │ false     │
# │ econ     │ main    │ sources_oa_incites              │ [id, issn_l, issn, display_name, host_organization, host_organization_name, host_organization_lineage, works_count, cited_by_count, summary_stats, is_oa, is_in_doaj, is_indexed_in_scopus, is_core, ids, homepage_url, apc_prices, apc_usd, country_code, societies, alternate_titles, abbreviated_title, type, topics, topic_share, x_concepts, counts_by_year, works_api_url, updated_date, created_date] │ [VARCHAR, VARCHAR, VARCHAR[], VARCHAR, VARCHAR, VARCHAR, VARCHAR[], BIGINT, BIGINT, STRUCT("2yr_mean_citedness" DOUBLE, h_index INTEGER, i10_index INTEGER), BOOLEAN, BOOLEAN, BOOLEAN, BOOLEAN, VARCHAR, VARCHAR, STRUCT(price INTEGER, currency VARCHAR)[], DOUBLE, VARCHAR, STRUCT(url VARCHAR, organization VARCHAR)[], VARCHAR[], VARCHAR, VARCHAR, STRUCT(id VARCHAR, display_name VARCHAR, count INTEGER, subfield STRUCT(id VARCHAR, display_name VARCHAR), field STRUCT(id VARCHAR, display_name VARCHAR), "domain" STRUCT(id VARCHAR, display_name VARCHAR))[], STRUCT(id VARCHAR, display_name VARCHAR, "value" DOUBLE, subfield STRUCT(id VARCHAR, display_name VARCHAR), field STRUCT(id VARCHAR, display_name VARCHAR), "domain" STRUCT(id VARCHAR, display_name VARCHAR))[], STRUCT(id VARCHAR, wikidata VARCHAR, display_name VARCHAR, "level" INTEGER, score DOUBLE)[], STRUCT("year" INTEGER, works_count INTEGER, cited_by_count INTEGER)[], VARCHAR, VARCHAR, VARCHAR] │ false     │
# │ econ     │ main    │ weighted_citations              │ [author_id, cite_count, citer_count_weighted]                                                                                                                                                                                                                                                                                                                                                                │ [VARCHAR, BIGINT, DOUBLE]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  │ false     │
# │ econ     │ main    │ weighted_citations_both         │ [author_id, citer_count, citer_count_weighted]                                                                                                                                                                                                                                                                                                                                                               │ [VARCHAR, BIGINT, DOUBLE]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  │ false     │
# │ econ     │ main    │ weighted_citations_institutions │ [author_id, citer_count, citer_count_weighted]                                                                                                                                                                                                                                                                                                                                                               │ [VARCHAR, BIGINT, DOUBLE]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  │ false     │
# │ econ     │ main    │ weighted_citations_sources      │ [author_id, citer_count, citer_count_weighted]                                                                                                                                                                                                                                                                                                                                                               │ [VARCHAR, BIGINT, DOUBLE]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  │ false     │
# │ econ     │ main    │ works                           │ [work_id, doi, title, display_name, publication_year, type, countries_distinct_count, institutions_distinct_count, fwci, has_fulltext, cited_by_count, is_retracted, is_paratext, referenced_works_count, cited_by_api_url, updated_date, created_date, is_authors_truncated, volume, issue, first_page, last_page, source_id, source_name, host_id, host_name]                                              │ [VARCHAR, VARCHAR, VARCHAR, VARCHAR, BIGINT, VARCHAR, BIGINT, BIGINT, DOUBLE, BOOLEAN, BIGINT, BOOLEAN, BOOLEAN, BIGINT, VARCHAR, VARCHAR, VARCHAR, BOOLEAN, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR, VARCHAR]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       │ false     │
# ├──────────┴─────────┴─────────────────────────────────┴──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┴────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┴───────────┤
# │ 22 rows                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            6 columns │
# └──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
#
# self.cache.check() = [<warnings.WarningMessage object at 0x798dd257a120>, <warnings.WarningMessage object at 0x798dd2578740>, <warnings.WarningMessage object at 0x798dd2578c20>, <warnings.WarningMessage object at 0x798dd44ed730>, <warnings.WarningMessage object at 0x798dd266d310>, <warnings.WarningMessage object at 0x798dd266dc70>, <warnings.WarningMessage object at 0x798dd266d1f0>, <warnings.WarningMessage object at 0x798dd266d820>, <warnings.WarningMessage object at 0x798dd266da60>, <warnings.WarningMessage object at 0x798dd266c710>, <warnings.WarningMessage object at 0x798dd266ea50>, <warnings.WarningMessage object at 0x798dd266dbb0>, <warnings.WarningMessage object at 0x798dd266d850>, <warnings.WarningMessage object at 0x798dd266d5b0>, <warnings.WarningMessage object at 0x798dd266f0e0>, <warnings.WarningMessage object at 0x798dd266ca40>, <warnings.WarningMessage object at 0x798dd266f1d0>, <warnings.WarningMessage object at 0x798dd266c7a0>, <warnings.WarningMessage object at 0x798dd266c1d0>, <warnings.WarningMessage object at 0x798dd266d6a0>, <warnings.WarningMessage object at 0x798dd266da30>, <warnings.WarningMessage object at 0x798dd266e2d0>, <warnings.WarningMessage object at 0x798dd266e270>, <warnings.WarningMessage object at 0x798dd266dca0>, <warnings.WarningMessage object at 0x798dd266f050>, <warnings.WarningMessage object at 0x798dd266cd70>, <warnings.WarningMessage object at 0x798dd266c2f0>, <warnings.WarningMessage object at 0x798dd266c170>, <warnings.WarningMessage object at 0x798dd266c320>, <warnings.WarningMessage object at 0x798dd266e300>, <warnings.WarningMessage object at 0x798dd266f290>, <warnings.WarningMessage object at 0x798dd266d790>, <warnings.WarningMessage object at 0x798dd266daf0>, <warnings.WarningMessage object at 0x798dd266f200>, <warnings.WarningMessage object at 0x798dd266c290>, <warnings.WarningMessage object at 0x798dd266f230>, <warnings.WarningMessage object at 0x798dd266f7a0>, <warnings.WarningMessage object at 0x798dd266e990>, <warnings.WarningMessage object at 0x798dd266e9c0>, <warnings.WarningMessage object at 0x798dd266db50>, <warnings.WarningMessage object at 0x798dd266dfd0>, <warnings.WarningMessage object at 0x798dd266e000>, <warnings.WarningMessage object at 0x798dd266dfa0>, <warnings.WarningMessage object at 0x798dd266e0f0>, <warnings.WarningMessage object at 0x798dd266f2f0>, <warnings.WarningMessage object at 0x798dd266e1e0>, <warnings.WarningMessage object at 0x798dd266e480>, <warnings.WarningMessage object at 0x798dd266e4e0>, <warnings.WarningMessage object at 0x798dd266f4a0>, <warnings.WarningMessage object at 0x798dd266c6e0>, <warnings.WarningMessage object at 0x798dd266e210>, <warnings.WarningMessage object at 0x798dd266cb00>, <warnings.WarningMessage object at 0x798dd266c530>, <warnings.WarningMessage object at 0x798dd266cb60>, <warnings.WarningMessage object at 0x798dd266cb30>, <warnings.WarningMessage object at 0x798dd266c1a0>, <warnings.WarningMessage object at 0x798dd266ee10>, <warnings.WarningMessage object at 0x798dd266fc80>, <warnings.WarningMessage object at 0x798dd266fd10>, <warnings.WarningMessage object at 0x798dd266fce0>, <warnings.WarningMessage object at 0x798dd266fcb0>, <warnings.WarningMessage object at 0x798dd266fbc0>, <warnings.WarningMessage object at 0x798dd266fef0>, <warnings.WarningMessage object at 0x798dd266fc20>, <warnings.WarningMessage object at 0x798dd266fc50>, <warnings.WarningMessage object at 0x798dd266faa0>, <warnings.WarningMessage object at 0x798dd266fbf0>, <warnings.WarningMessage object at 0x798dd266fe90>, <warnings.WarningMessage object at 0x798dd266fad0>, <warnings.WarningMessage object at 0x798dd266fb00>, <warnings.WarningMessage object at 0x798dd266f980>, <warnings.WarningMessage object at 0x798dd266c4d0>, <warnings.WarningMessage object at 0x798dd266fec0>, <warnings.WarningMessage object at 0x798dd266f9b0>, <warnings.WarningMessage object at 0x798dd266f9e0>, <warnings.WarningMessage object at 0x798dd266eae0>, <warnings.WarningMessage o ...
# self.cache.volume() = 14954475268
# ┌──────────────────────────────────┬──────────────────────────────────┬─────────┐
# │             citer_id             │             cited_id             │ weights │
# │             varchar              │             varchar              │  int64  │
# ├──────────────────────────────────┼──────────────────────────────────┼─────────┤
# │ https://openalex.org/S175056054  │ https://openalex.org/S175056054  │   33468 │
# │ https://openalex.org/S94499970   │ https://openalex.org/S94499970   │   29348 │
# │ https://openalex.org/S94499970   │ https://openalex.org/S175056054  │   12526 │
# │ https://openalex.org/S173966628  │ https://openalex.org/S173966628  │   12063 │
# │ https://openalex.org/S136211407  │ https://openalex.org/S136211407  │   11161 │
# │ https://openalex.org/S96305778   │ https://openalex.org/S96305778   │   10834 │
# │ https://openalex.org/S80150607   │ https://openalex.org/S80150607   │   10010 │
# │ https://openalex.org/S159637997  │ https://openalex.org/S159637997  │    9776 │
# │ https://openalex.org/S85457386   │ https://openalex.org/S85457386   │    8508 │
# │ https://openalex.org/S141184754  │ https://openalex.org/S141184754  │    8360 │
# │                ·                 │                ·                 │       · │
# │                ·                 │                ·                 │       · │
# │                ·                 │                ·                 │       · │
# │ https://openalex.org/S945769174  │ https://openalex.org/S175056054  │      44 │
# │ https://openalex.org/S129650269  │ https://openalex.org/S168273071  │      44 │
# │ https://openalex.org/S54467454   │ https://openalex.org/S86125002   │      44 │
# │ https://openalex.org/S155526628  │ https://openalex.org/S45372229   │      44 │
# │ https://openalex.org/S180723199  │ https://openalex.org/S180061323  │      44 │
# │ https://openalex.org/S45372229   │ https://openalex.org/S4210209722 │      44 │
# │ https://openalex.org/S165058066  │ https://openalex.org/S72880728   │      44 │
# │ https://openalex.org/S44585919   │ https://openalex.org/S76440981   │      44 │
# │ https://openalex.org/S2898237991 │ https://openalex.org/S80150607   │      44 │
# │ https://openalex.org/S136211407  │ https://openalex.org/S178258306  │      44 │
# ├──────────────────────────────────┴──────────────────────────────────┴─────────┤
# │ ? rows (>9999 rows, 20 shown)                                       3 columns │
# └───────────────────────────────────────────────────────────────────────────────┘
#
# temp.shape = (553, 9)
# ...
# ├──────────┴─────────┴─────────────────────────────────┴──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┴────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┴───────────┤
# │ 22 rows                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            6 columns │
# └──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
#
# self.cache.check() = [<warnings.WarningMessage object at 0x798dd464b230>, <warnings.WarningMessage object at 0x798ddf332c30>, <warnings.WarningMessage object at 0x798ddf3303b0>, <warnings.WarningMessage object at 0x798dd42f2270>, <warnings.WarningMessage object at 0x798dd243b3e0>, <warnings.WarningMessage object at 0x798dd2439040>, <warnings.WarningMessage object at 0x798ddf3328a0>, <warnings.WarningMessage object at 0x798dd41f38f0>, <warnings.WarningMessage object at 0x798dde6f4f20>, <warnings.WarningMessage object at 0x798dde6f67e0>, <warnings.WarningMessage object at 0x798dca144650>, <warnings.WarningMessage object at 0x798dde6f6c60>, <warnings.WarningMessage object at 0x798dd6145520>, <warnings.WarningMessage object at 0x798dd40fbb00>, <warnings.WarningMessage object at 0x798dd25636b0>, <warnings.WarningMessage object at 0x798dd40485f0>, <warnings.WarningMessage object at 0x798dd4049df0>, <warnings.WarningMessage object at 0x798dd4049400>, <warnings.WarningMessage object at 0x798dd40fa300>, <warnings.WarningMessage object at 0x798dd257b560>, <warnings.WarningMessage object at 0x798de151b1d0>, <warnings.WarningMessage object at 0x798dd40c1e20>, <warnings.WarningMessage object at 0x798dd40c0e00>, <warnings.WarningMessage object at 0x798dd40c1fd0>, <warnings.WarningMessage object at 0x798dd6c6b1a0>, <warnings.WarningMessage object at 0x798dd633d100>, <warnings.WarningMessage object at 0x798dd42cc410>, <warnings.WarningMessage object at 0x798dd42ceab0>, <warnings.WarningMessage object at 0x798dd42cdca0>, <warnings.WarningMessage object at 0x798dd42cc950>, <warnings.WarningMessage object at 0x798dd42cc9e0>, <warnings.WarningMessage object at 0x798dd42cda30>, <warnings.WarningMessage object at 0x798dd42cc6b0>, <warnings.WarningMessage object at 0x798dd42cdeb0>, <warnings.WarningMessage object at 0x798dd6c683e0>, <warnings.WarningMessage object at 0x798dd42ce750>, <warnings.WarningMessage object at 0x798dd418da60>, <warnings.WarningMessage object at 0x798dd418d070>, <warnings.WarningMessage object at 0x798dd418c6e0>, <warnings.WarningMessage object at 0x798dd418ffe0>, <warnings.WarningMessage object at 0x798dd418c110>, <warnings.WarningMessage object at 0x798dd418f1d0>, <warnings.WarningMessage object at 0x798dd418f7a0>, <warnings.WarningMessage object at 0x798dd418e450>, <warnings.WarningMessage object at 0x798dd418cad0>, <warnings.WarningMessage object at 0x798dd418db80>, <warnings.WarningMessage object at 0x798de153ca10>, <warnings.WarningMessage object at 0x798dde6579b0>, <warnings.WarningMessage object at 0x798dde657770>, <warnings.WarningMessage object at 0x798dd418fa10>, <warnings.WarningMessage object at 0x798de6302900>, <warnings.WarningMessage object at 0x798de6303920>, <warnings.WarningMessage object at 0x798de6300d40>, <warnings.WarningMessage object at 0x798de6301e50>, <warnings.WarningMessage object at 0x798de6303f50>, <warnings.WarningMessage object at 0x798de6302270>, <warnings.WarningMessage object at 0x798de6302d20>, <warnings.WarningMessage object at 0x798de6302ba0>, <warnings.WarningMessage object at 0x798de6300f20>, <warnings.WarningMessage object at 0x798de63031d0>, <warnings.WarningMessage object at 0x798de6301100>, <warnings.WarningMessage object at 0x798de6302de0>, <warnings.WarningMessage object at 0x798dde6571d0>, <warnings.WarningMessage object at 0x798ddd46df10>, <warnings.WarningMessage object at 0x798ddd46d2e0>, <warnings.WarningMessage object at 0x798ddd46d3d0>, <warnings.WarningMessage object at 0x798ddd46f470>, <warnings.WarningMessage object at 0x798ddd46c710>, <warnings.WarningMessage object at 0x798ddd46d100>, <warnings.WarningMessage object at 0x798ddd46c170>, <warnings.WarningMessage object at 0x798ddd46c320>, <warnings.WarningMessage object at 0x798ddd46c350>, <warnings.WarningMessage object at 0x798ddd46f230>, <warnings.WarningMessage object at 0x798ddd46dc10>, <warnings.WarningMessage object at 0x798ddd46db20>, <warnings.WarningMessage object at 0x798ddd46f980>, <warnings.WarningMessage o ...
# self.cache.volume() = 14954475268
# ┌──────────────────────────────────┬──────────────────────────────────┬─────────┐
# │             citer_id             │             cited_id             │ weights │
# │             varchar              │             varchar              │  int64  │
# ├──────────────────────────────────┼──────────────────────────────────┼─────────┤
# │ https://openalex.org/S175056054  │ https://openalex.org/S175056054  │   33468 │
# │ https://openalex.org/S94499970   │ https://openalex.org/S94499970   │   29348 │
# │ https://openalex.org/S94499970   │ https://openalex.org/S175056054  │   12526 │
# │ https://openalex.org/S173966628  │ https://openalex.org/S173966628  │   12063 │
# │ https://openalex.org/S136211407  │ https://openalex.org/S136211407  │   11161 │
# │ https://openalex.org/S96305778   │ https://openalex.org/S96305778   │   10834 │
# │ https://openalex.org/S80150607   │ https://openalex.org/S80150607   │   10010 │
# │ https://openalex.org/S159637997  │ https://openalex.org/S159637997  │    9776 │
# │ https://openalex.org/S85457386   │ https://openalex.org/S85457386   │    8508 │
# │ https://openalex.org/S141184754  │ https://openalex.org/S141184754  │    8360 │
# │                ·                 │                ·                 │       · │
# │                ·                 │                ·                 │       · │
# │                ·                 │                ·                 │       · │
# │ https://openalex.org/S945769174  │ https://openalex.org/S175056054  │      44 │
# │ https://openalex.org/S129650269  │ https://openalex.org/S168273071  │      44 │
# │ https://openalex.org/S54467454   │ https://openalex.org/S86125002   │      44 │
# │ https://openalex.org/S155526628  │ https://openalex.org/S45372229   │      44 │
# │ https://openalex.org/S180723199  │ https://openalex.org/S180061323  │      44 │
# │ https://openalex.org/S45372229   │ https://openalex.org/S4210209722 │      44 │
# │ https://openalex.org/S165058066  │ https://openalex.org/S72880728   │      44 │
# │ https://openalex.org/S44585919   │ https://openalex.org/S76440981   │      44 │
# │ https://openalex.org/S2898237991 │ https://openalex.org/S80150607   │      44 │
# │ https://openalex.org/S136211407  │ https://openalex.org/S178258306  │      44 │
# ├──────────────────────────────────┴──────────────────────────────────┴─────────┤
# │ ? rows (>9999 rows, 20 shown)                                       3 columns │
# └───────────────────────────────────────────────────────────────────────────────┘
#
# temp.shape = (553, 9)
#       kind                         cited_id  citation_count  pageRank                            citer                                                label  in_degree  out_degree    panel
# 0  Sources  https://openalex.org/S160393188          2497.0  0.001380  https://openalex.org/S160393188  Journal of the Japanese and International Economies      331.0       238.0  Sources
# 1  Sources   https://openalex.org/S61808140         10012.0  0.002678   https://openalex.org/S61808140                   The Journal of Development Studies      444.0       342.0  Sources
# 2  Sources  https://openalex.org/S115237062          3917.0  0.001673  https://openalex.org/S115237062           Journal of Economics & Management Strategy      336.0       231.0  Sources
# 3  Sources   https://openalex.org/S34280410          4034.0  0.001493   https://openalex.org/S34280410                     Journal of Productivity Analysis      325.0       269.0  Sources
# 4  Sources   https://openalex.org/S14468722          5440.0  0.001858   https://openalex.org/S14468722                    Journal of Agricultural Economics      309.0       244.0  Sources
# temp.shape = (1444, 9)
#            kind                         cited_id  citation_count  pageRank                            citer                             label  in_degree  out_degree         panel
# 0  Institutions  https://openalex.org/I103531236     2967.690265  0.001714  https://openalex.org/I103531236                    Boston College     1341.0       851.0  Institutions
# 1  Institutions  https://openalex.org/I913481162     2232.514626  0.000886  https://openalex.org/I913481162  Wageningen University & Research     1187.0      1071.0  Institutions
# 2  Institutions  https://openalex.org/I177477856      365.471032  0.000438  https://openalex.org/I177477856   Polytechnic University of Turin      627.0       846.0  Institutions
# 3  Institutions  https://openalex.org/I204250578     2090.979798  0.001237  https://openalex.org/I204250578  University of California, Irvine     1272.0       915.0  Institutions
# 4  Institutions    https://openalex.org/I4577782      864.515821  0.000652    https://openalex.org/I4577782     Technische Universität Berlin     1032.0       964.0  Institutions
# temp.shape = (1997, 9)
#       kind                          cited_id  citation_count  pageRank                             citer                                                         label  in_degree  out_degree panel
# 0  Sources   https://openalex.org/S193530623          1416.0  0.000338   https://openalex.org/S193530623                Studies in Nonlinear Dynamics and Econometrics      934.0      1185.0  Both
# 1  Sources    https://openalex.org/S47824075           849.0  0.000296    https://openalex.org/S47824075                                        Global Economic Review      664.0      1002.0  Both
# 2  Sources  https://openalex.org/S2764640640           582.0  0.000315  https://openalex.org/S2764640640                            Baltic Journal of Economic Studies      129.0       592.0  Both
# 3  Sources  https://openalex.org/S4210198543          1666.0  0.000301  https://openalex.org/S4210198543  Journal of Agribusiness in Developing and Emerging Economies      382.0      1022.0  Both
# 4  Sources    https://openalex.org/S76295336           294.0  0.000266    https://openalex.org/S76295336                                    Journal of Media Economics      318.0       375.0  Both
#       Alone      Both                                                                                               Name    panel
# 0  0.904339  0.062599  Revista Eletrônica Internacional de Economia Política da Informação da Comunicação e da Cultura c  Sources
# 1  0.183107  0.028180                                       International journal of ecological economics and statistics  Sources
# 2  0.226823  0.025089                                                          Statistika Statistics and Economy Journal  Sources
# 3  0.301991  0.025063                                                                        Custos e @gronegócio online  Sources
# 4  0.113020  0.013926                                                                                Cuadernos del CLAEH  Sources
#               Alone  Both  Name
# panel
# Institutions   1444  1444  1444
# Sources         553   553   553
# DONE!
