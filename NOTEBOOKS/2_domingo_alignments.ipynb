# %%
# %run common_setup.ipynb

# %%
import glob
import re
class MatchDomingoSourceInstitutionSamples(SetUp):

    def __init__(self):
        super().__init__()
        return
    
    def special_issn(self):
        special_issn = {'economic research-ekonomska istrazivanja': ['1331-677X'], # '1848-9664'],
                                'finanzarchiv': 	['0015-2218'],
                                'journal of the knowledge economy': 	['1868-7865'], #, '1868-7873'],
                                'latin american economic review': 	['2196-436X']} #, '2198-3526']}
        df = pd.DataFrame.from_dict(special_issn, orient='index').reset_index()
        df.columns = ['Journal name', 'ISSN']
        print(df.head())
        self.db.sql("CREATE OR REPLACE TABLE memory.specials AS (SELECT * FROM df)")
        self.db.sql("SELECT * FROM memory.specials").show()
        return
    
    def extract_jcr(self):
        df_list = []
        for file in glob.glob('../DATA/WOS_JCR/*.xlsx'):
            df_list.append(pd.read_excel(file, skiprows=2))
        df = pd.concat(df_list).drop_duplicates()
        for row in df.itertuples():
            if not isinstance(row.ISSN, str):
                df.at[row.Index, 'ISSN'] = row.eISSN
        print(f'{df.shape = }\n{df.head()}')
        self.db.sql("CREATE OR REPLACE TABLE memory.wos_jcr AS (SELECT * FROM df)")
        self.db.sql("SELECT * FROM memory.wos_jcr").show()
        self.db.sql("COPY memory.wos_jcr TO '../DATA/wos_jcr.csv' (HEADER, DELIMITER ',')")
        return

    def extract_journals_institutions(self):
        df_dd = pd.read_excel('../DATA/eco_bus_inst_journal_scores.xlsx', sheet_name=None)
        for kind in ['journals', 'institutions']:
            df = self._tidy_journals(df=df_dd[kind]) if kind == 'journals' else df_dd[kind]
            df = df.drop(columns=['Unnamed: 0'])
            print(f'{df.shape = }\n{df.head()}')
            self.db.sql(f"CREATE OR REPLACE TABLE memory.{kind} AS (SELECT * FROM df)")
            self.db.sql(f"SELECT * FROM memory.{kind}").show()
        return

    def _tidy_journals(self, df=None):
        df = df.replace(to_replace='(?i)^Economics and Philosophy$', value='economics & philosophy', regex=True) 
        df = df.replace(to_replace='(?i)^revista de historia economica$', value='Revista de Historia Economica-Journal of Iberian and Latin American Economic History', regex=True)
        df = df.replace(to_replace='(?i)^spanish journal of finance and accounting-revista espanola de financiacion y contabilida$', value=
                                 'spanish journal of finance and accounting-revista espanola de financiacion y contabilidad', regex=True)
        df = df.replace(to_replace='(?i)BUSINESS ETHICS-A EUROPEAN REVIEW', value='BUSINESS ETHICS THE ENVIRONMENT & RESPONSIBILITY'.capitalize(), regex=True)
        return df
    
    def match_sources(self):
        # self.db.sql("SELECT * FROM memory.journals WHERE contains(lower(journal), 'ethics')").show()
        sql = """
            CREATE OR REPLACE TABLE project.jcr_matches AS
            SELECT DISTINCT ON (journal)
                    jcr_journal,
                    ISSN AS issn,
                    journal,
                    pub,
                FROM journals j
                LEFT JOIN 
                    (SELECT "Journal name" as jcr_journal,
                            ISSN
                        FROM memory.wos_jcr
                     UNION
                     SELECT "Journal name" as jcr_journal,
                            ISSN
                        FROM memory.specials s
                    )
                ON lower(journal) = lower(jcr_journal)
                -- WHERE ISSN IS NULL
                ORDER BY journal
            """
        self.db.sql(sql)
        self.db.sql("SELECT count(*) FROM project.jcr_matches").show()
        self.db.sql("SELECT * FROM project.jcr_matches").show()
        return
    
    def match_institutions(self):
        df = self.db.sql("SELECT * FROM memory.institutions").df() #.iloc[:64]
        df['institution_normal'] = [re.sub(r'\([^()]*\)', '', name.replace(r'&', 'and').replace(r' - ', ' ').replace(',', '').replace("'", "")) for name in df['institution']]
        print(f'{df.shape = }\n{df.head()}')
        results = []
        for row in df.itertuples():
            institution = row.institution_normal
            response = self._cache_manager(task = f"Institutions().autocomplete('{institution}')")
            if not isinstance(response, pd.DataFrame) or len(response) == 0:
                print(f'MISSED {institution} {row.institution}')
            else:
                response.insert(1, 'esi_name', row.institution)
                response = response.head(1)
                results.append(response)
        matched = pd.concat(results)
        print(f'{matched.shape = }\n{matched.head()}')
        unmatched = df[~df.institution.isin(matched.esi_name)]
        print(f'{unmatched.shape = }\n{unmatched.head()}')
        self._match_institutions_2(df=unmatched)
        return
    
    def _match_institutions_2(self, df=None):
        print(f'{df.shape = }\n{df.head()}') # type: ignore
        self.db.sql("SELECT * FROM institutions.ror").show()
        oa = self.db.sql("SELECT name, institution_id FROM institutions.ror").df()
        print(oa.head())
        dd = dict(zip(oa['name'], oa.institution_id))
        found, not_found = 0, 0
        for institution in df['institution']:
            ror = dd.get(institution)
            if ror is None:
                print("MISSED ", institution, not_found)
                not_found += 1
                continue
            print("FOUND ", institution, found)
            found += 1
        return

# %% [markdown]
# #### This cell matches Domingo's C and T (and CT) lists to authors in the OpenAlex corpus
# #### It also creates the X and Y samples from OpenAlex
#
# - Extract Domingo's list and ensure that the names are normalised
# - Match Domingo' Names to OpenAlex display_names
# - Allocate the T, C, TC, X and Y samples

# %%
class MatchDomingoAuthorSample(SetUp):

    def __init__(self):
        super().__init__()
        return    

    def extract_sample(self):
        sample = pd.read_excel('../DATA/researchers_results_total_average_influence.xlsx').iloc[:, :10]
        sample[['first', 'middle', 'last', 'fullname']] = [normalise_name(n) for n in sample.Research_Profile]
        print(f'{sample.shape = }\n{sample.head()}')
        sample = sample.sort_values('HCP', ascending=False).reset_index(drop=True)
        print(sample[sample.duplicated(keep=False)].head(32))
        self.db.sql("CREATE OR REPLACE TABLE project.domingo_sample_original AS SELECT * FROM sample")
        self.sample = self.db.sql("SELECT * FROM project.domingo_sample_original").df()
        print(f'{sample.shape = }\n{sample.head()}')
        return
    
    def match_sample(self):
        sql = """   
            -- MATCH Domingo's EconBus list to OpenAlex
            -- matches on full name and first intial/last name
            -- finds 1280 matches (many duplicates)
            -- finds 293 distinct matches from endogenous authors
            -- finds 26 non-matching WOS names, no duplicates.
            -- there are 15 "complex" names matched by hand
            -- 
            -- ========================================
            CREATE OR REPLACE TABLE project.candidates AS
            WITH 
                match_endogenous_CTE AS
                (SELECT a.author_id,
                        a.orcid,
                        a.works_count,
                        PUB,
                        PUB/a.works_count AS works_fraction,
                        a.cited_by_count,
                        CIT,
                        CIT/a.cited_by_count AS cite_fraction,
                        a.author_name,
                        a.fullname AS oa_fullname,
                        aa.topics[1].field.display_name AS field,
                        Research_Profile,
                        "Group",
                        "class",
                        d."first",
                        d.middle,
                        d."last",
                        d.fullname,
                    FROM project.domingo_sample_original d
                    LEFT JOIN project.authors_full a
                    ON list_contains(display_name_alternatives, d.fullname) OR list_contains(display_name_alternatives, concat(d.first[1],'. ', d.last))
                    LEFT JOIN project.authors aa
                    USING (author_id)
                    ORDER BY d.fullname, a.works_count DESC
                    ),
                filtered_endogenous_CTE AS
                    (SELECT m.*
                    FROM match_endogenous_CTE m
                    WHERE list_contains(['Agricultural and Biological Sciences', 'Arts and Humanities', 'Environmental Science',
                                            'Energy', 'Psychology', -- 'Decision Sciences', 'Mathematics'
                                            'Biochemistry, Genetics and Molecular Biology', 'Computer Science',
                                            'Chemical Engineering', 'Earth and Planetary Sciences', 'Engineering', 
                                            'Materials Science' , 'Medicine', 'Neuroscience', 'Physics and Astronomy'], field) = false
                    ),
                endogenous_matched_CTE AS
                    (SELECT DISTINCT ON (Research_Profile)
                            * 
                    FROM filtered_endogenous_CTE
                    ORDER BY Research_Profile, works_count DESC
                    ),
                exogenous_match_CTE AS  
                    (SELECT oa.id AS author_id,
                            oa.orcid,
                            oa.works_count,
                            PUB,
                            PUB/oa.works_count AS works_fraction,
                            oa.cited_by_count,
                            CIT,
                            CIT/oa.cited_by_count AS cite_fraction,
                            oa.display_name AS author_name,
                            oa.display_name AS oa_fullname,
                            oa.topics[1].field.display_name AS field,
                            Research_Profile,
                            "Group",
                            "class",
                            "first",
                            middle,
                            "last",
                            fullname
                        FROM match_endogenous_CTE e
                        LEFT JOIN authors.authors oa
                        ON list_contains(oa.display_name_alternatives, e.fullname) OR list_contains(oa.display_name_alternatives, concat(e.first[1],'. ', e.last))
                        WHERE (e.author_id IS NULL) AND 
                            (field is NULL OR list_contains(['Physics and Astronomy', 'Earth and Planetary Sciences', 
                                            'Biochemistry, Genetics and Molecular Biology', 'Medicine', 
                                            'Veterinary', 'Engineering', 'Neuroscience', 'Nursing',
                                            'Health Professions', 'Materials Science'], field) = false) 
                        ORDER BY Research_Profile, oa.works_count DESC
                    ),
                difficult_names_CTE AS
                (SELECT oa.id AS author_id,
                        oa.orcid,
                        oa.works_count,
                        PUB,
                        PUB/oa.works_count AS works_fraction,
                        oa.cited_by_count,
                        CIT,
                        CIT/oa.cited_by_count AS cite_fraction,
                        oa.display_name AS author_name,
                        oa.display_name AS oa_fullname,
                        oa.topics[1].field.display_name AS field,
                        Research_Profile,
                        "Group",
                        "class",
                        "first",
                        middle,
                        "last",
                        fullname
                    FROM '/home/lc/Projects/EconomicsBusiness/DATA/difficult_name_matches.csv'
                    LEFT JOIN project.domingo_sample_original d
                    USING (Research_Profile)
                    LEFT JOIN authors.authors oa
                    ON id = author_id
                ),
                openalex_kind_CTE AS
                (SELECT author_id,
                        orcid,
                        works_count,
                        NULL AS PUB,
                        NULL AS works_fraction,
                        cited_by_count,
                        NULL AS CIT,
                        NULL AS cite_fraction,
                        author_name,
                        fullname AS oa_fullname,
                        topics[1].field.display_name AS field,
                        NULL AS Research_Profile,
                        'X' AS "Group",
                        NULL AS "class",
                        NULL AS "first",
                        NULL AS middle,
                        NULL AS "last",
                        NULL AS fullname
                        -- row_number() OVER (ORDER BY works_count DESC) AS row_count
                    FROM project.authors_full a
                    WHERE list_contains((SELECT list(author_id) FROM project.candidates GROUP BY ALL), author_id) = false
                            AND list_contains(['Economics, Econometrics and Finance'], field) --'Decision Sciences',  'Social Sciences'], field)
                    LIMIT 150
                    )

                        -- SELECT 'openalex' AS kind,
                        --         *
                        --   FROM openalex_kind_CTE

            SELECT *
            FROM
                (SELECT 'endogenous' AS kind,
                            *
                        FROM endogenous_matched_CTE
                    UNION  
                        SELECT DISTINCT ON (Research_Profile)
                            'exogenous' AS kind,
                                *
                        FROM exogenous_match_CTE
                        WHERE author_id IS NOT NULL
                    UNION
                        SELECT DISTINCT ON (Research_Profile)
                                'unmatched' AS kind,
                                *
                        FROM exogenous_match_CTE
                        WHERE author_id IS NULL
                    UNION
                        SELECT DISTINCT ON (Research_Profile)
                                'matched_difficult' AS kind,
                                *
                        FROM difficult_names_CTE
                    UNION
                        SELECT 'openalex' AS kind,
                                *
                        FROM openalex_kind_CTE
                    )
            """
        self.db.sql(sql)  #.show()
        return

    def load_sample(self):
        print('load matched sample together with author data from OA')
        sample= self.db.sql("SELECT * FROM project.candidates").df().sort_values('Research_Profile').reset_index(drop=True)
        print(f'{sample.shape = } {sample['kind'].unique() = }\n{sample.head()}\n{sample.loc[[s is None for s in sample.kind], :].head()}')
        with pd.ExcelWriter('../DATA/domingo_sample_match.xlsx') as writer:
            sample.to_excel(writer, index=False, sheet_name='all_data')
            sample.query("kind == 'endogenous'").to_excel(writer, index=False, sheet_name='endogenous')
            sample.query("kind == 'exogenous'").to_excel(writer, index=False, sheet_name='exogneous')
            sample.query("kind == 'unmatched'").to_excel(writer, index=False, sheet_name='unmatched')
            sample.query("kind == 'matched_difficult'").to_excel(writer, index=False, sheet_name='unmatched')
            sample.query("kind == 'openalex'").to_excel(writer, index=False, sheet_name='openalex')
            sample.loc[[k is None for k in sample["kind"]], :].to_excel(writer, index=False, sheet_name='unmatched_')
            sample.loc[[k is not None for k in sample["author_id"]], :].to_excel(writer, index=False, sheet_name='best_case')
        return

# %%
class ETLForDomingo(SetUp):

    def __init__(self):
        super().__init__()
        self.assemble_tables = {}
        return
    
    def match_table(self):
        sql = """  
            -- MATCH Domingo's EconBus list to OpenAlex
            -- ========================================
            SELECT *
            FROM project.candidates
        """
        sample = self.db.sql(sql).df()
        sample = sample.sort_values(['Group', 'Research_Profile'], ascending=[False, True]).reset_index(drop=True)
        print(f'{sample.shape = }\n{sample.head()}')
        self.assemble_tables |= {'Domingo_matched': sample}
        return
    
    def works_table(self):
        sql = """
            -- ETL works for Domingo
            -- =====================
            SELECT id as work_id,
                    doi, 
                    title, 
                    publication_year,
                    fwci,
                    cited_by_count,
                    referenced_works_count,
                    "primary_location.source".display_name AS source_name,
                    "primary_location.source".issn_l AS issn,
                    "primary_location.source".host_organization_name AS publisher,
                    "biblio.volume" AS volume,
                FROM project.raw
            """
        works = self.db.sql(sql).df()
        works = works.sort_values(['publication_year', 'fwci'], ascending=[True, False]).reset_index(drop=True)
        print(f'{works.shape = }\n{works.head()}')
        self.assemble_tables |= {'works': works}
        return
    
    def authorships_table(self):
        sql = """
            -- ETL FOR Domingo authors and institutions
            -- ========================================
            SELECT work_id,
                    author_name,
                    author_id,
                    institution.display_name AS institution_name,
                    institution.id AS institution_id,
                    institution.country_code AS country_code
            FROM
                (SELECT work_id,
                    authorship.author.display_name as author_name,
                    authorship.author.id AS author_id,
                    unnest(authorship.institutions) AS institution,
                FROM 
                    (SELECT id AS work_id,
                        unnest(authorships) AS authorship
                    FROM project.raw
                    )
                )
                """
        authorships = self.db.sql(sql).df()
        print(f"{authorships.shape = }\n{authorships.head()}")
        self.assemble_tables |= {'authorships': authorships}
        return
    
    def references_table(self):
        sql = """
            -- ETL FOR Domingo reference_list
            -- ==============================
            SELECT id AS work_id,
                    referenced_works
                FROM project.raw
            """
        references = self.db.sql(sql).df()
        print(f'{references.shape = }\n{references.head()}')
        self.assemble_tables |= {'references': references}
        return
    
    def citations_table(self):
        sql = """
            -- ETL FOR Domingo citation_list
            -- ==============================
            SELECT cited_id,
                    list(citer_id) AS citing_works_list
            FROM 
                (SELECT id AS citer_id,
                    unnest(referenced_works) AS cited_id
                FROM project.raw
                )
            GROUP BY ALL
            """
        citations = self.db.sql(sql).df()
        print(f'{citations.shape = }\n{citations.head()}')
        self.assemble_tables |= {'citations': citations}
        return
    
    def topics_table(self):
        sql = """ 
            -- ETL FOR Domingo topics
            -- ======================
            SELECT id AS work_id,
                    "primary_topic.display_name" AS topic_name,
                    "primary_topic.subfield".display_name AS subfield_name,
                    "primary_topic.field".display_name AS field_name,
                    "primary_topic.domain".display_name AS domain_name,
                    "primary_topic.score" AS topic_score
            FROM project.raw
            """
        topics = self.db.sql(sql).df()
        print(f'{topics.shape = }\n{topics.head()}')
        self.assemble_tables |= {'topics': topics}
        return


    def load_tables(self):
        for k, v in self.assemble_tables.items():
            with open(f'../DATA/tables_for_Domingo_{k}.csv', 'w') as writer:
                print(f'{k = } {v.shape = }\n{v.head()}')
                v.to_csv(writer, index=False)

# %%
def main():

    mdsis = MatchDomingoSourceInstitutionSamples()
    mdsis.extract_jcr()
    mdsis.extract_journals_institutions()
    mdsis.match_institutions()
    mdsis.db.close()
    
    # etl = ETLForDomingo()
    # etl.match_table()
    # etl.works_table()
    # etl.authorships_table()
    # etl.references_table()
    # etl.citations_table()
    # etl.topics_table()
    # etl.load_tables()
    # etl.db.close()

    return

# %%
if __name__ == "__main__":
    main()
    print("DONE")
# Out:
# ┌──────────────┬─────────┬──────────────────────┬──────────────────────┬───────────────────────────────────┬───────────┐
# │   database   │ schema  │         name         │     column_names     │           column_types            │ temporary │
# │   varchar    │ varchar │       varchar        │      varchar[]       │             varchar[]             │  boolean  │
# ├──────────────┼─────────┼──────────────────────┼──────────────────────┼───────────────────────────────────┼───────────┤
# │ authors      │ main    │ authors              │ [id, orcid, displa…  │ [VARCHAR, VARCHAR, VARCHAR, VAR…  │ false     │
# │ backup       │ main    │ authors              │ [author_id, orcid,…  │ [VARCHAR, VARCHAR, VARCHAR, VAR…  │ false     │
# │ backup       │ main    │ authors_full         │ [author_id, orcid,…  │ [VARCHAR, VARCHAR, VARCHAR, VAR…  │ false     │
# │ backup       │ main    │ authorships          │ [work_id, author_i…  │ [VARCHAR, VARCHAR, VARCHAR, VAR…  │ false     │
# │ backup       │ main    │ citer_cited          │ [citer_id, citer_y…  │ [VARCHAR, BIGINT, VARCHAR, BIGI…  │ false     │
# │ backup       │ main    │ domingo_sample_ori…  │ [Research_Profile,…  │ [VARCHAR, VARCHAR, BIGINT, BIGI…  │ false     │
# │ backup       │ main    │ raw                  │ [id, doi, title, p…  │ [VARCHAR, VARCHAR, VARCHAR, BIG…  │ false     │
# │ backup       │ main    │ sources_oa_incites   │ [column00, id, iss…  │ [BIGINT, VARCHAR, VARCHAR, VARC…  │ false     │
# │ backup       │ main    │ topics               │ [work_id, topic_id…  │ [VARCHAR, VARCHAR, VARCHAR, DOU…  │ false     │
# │ institutions │ main    │ institutions         │ [id, ror, display_…  │ [VARCHAR, VARCHAR, VARCHAR, VAR…  │ false     │
# │    ·         │  ·      │      ·               │          ·           │             ·                     │   ·       │
# │    ·         │  ·      │      ·               │          ·           │             ·                     │   ·       │
# │    ·         │  ·      │      ·               │          ·           │             ·                     │   ·       │
# │ project      │ main    │ source_edge_list     │ [citer_unit, cited…  │ [VARCHAR, VARCHAR, BIGINT]        │ false     │
# │ project      │ main    │ sources_oa_incites   │ [column00, id, iss…  │ [BIGINT, VARCHAR, VARCHAR, VARC…  │ false     │
# │ project      │ main    │ topics               │ [work_id, topic_id…  │ [VARCHAR, VARCHAR, VARCHAR, DOU…  │ false     │
# │ sources      │ main    │ sources              │ [id, issn_l, issn,…  │ [VARCHAR, VARCHAR, VARCHAR[], V…  │ false     │
# │ works        │ main    │ abstracts            │ [work_id, abstract…  │ [VARCHAR, MAP(VARCHAR, BIGINT[])] │ false     │
# │ works        │ main    │ authorships          │ [work_id, author_i…  │ [VARCHAR, VARCHAR, VARCHAR, VAR…  │ false     │
# │ works        │ main    │ citer_cited          │ [work_id, cited_id…  │ [VARCHAR, VARCHAR[]]              │ false     │
# │ works        │ main    │ reverted_abstracts   │ [work_id, abstract]  │ [VARCHAR, VARCHAR]                │ false     │
# │ works        │ main    │ topics               │ [work_id, topics]    │ [VARCHAR, STRUCT(id VARCHAR, di…  │ false     │
# │ works        │ main    │ works                │ [work_id, doi, tit…  │ [VARCHAR, VARCHAR, VARCHAR, VAR…  │ false     │
# ├──────────────┴─────────┴──────────────────────┴──────────────────────┴───────────────────────────────────┴───────────┤
# │ 35 rows (20 shown)                                                                                         6 columns │
# └──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
#
# self.cache.check() = []
# self.cache.volume() = 88538803655
# df.shape = (3543, 31)
#                            Journal name      JCR Abbreviation               Publisher       ISSN      eISSN                         Category Edition Total Citations 2024 JIF JIF Quartile  2024 JCI % of Citable OA JIF Rank 5 Year JIF 5 Year JIF Quartile JIF Without Self Cites Immediacy Index JCI Rank JCI Quartile  JCI Percentile  Eigenfactor  Normalized Eigenfactor  Article Influence Score  JIF Percentile AIS Quartile AIS Rank Citable Items % of Articles in Citable items  Cited Half-Life  Citing Half-Life Total Articles
# 0  JOURNAL OF MEDICAL INTERNET RESEARCH    J MED INTERNET RES  JMIR PUBLICATIONS, INC  2071-1050        NaN  HEALTH CARE SCIENCES & SERVICES    SCIE          50,249      6.0           Q1      1.58          97.83%   12/185        6.9                  Q1                    5.6             0.8   16/185           Q1           91.62      0.06742                15.00204                    1.757            93.8           Q1   23/169           950                         80.63%              4.5               5.6            766
# 1      JOURNAL OF CLINICAL EPIDEMIOLOGY      J CLIN EPIDEMIOL    ELSEVIER SCIENCE INC  0895-4356  1878-5921  HEALTH CARE SCIENCES & SERVICES    SCIE          43,370      5.2           Q1      1.84          37.44%   15/185        7.5                  Q1                    4.7             1.0   12/185           Q1           93.78      0.02670                 5.94292                    3.070            92.2           Q1    6/169           209                         81.82%             13.6               6.4            171
# 2          BMC HEALTH SERVICES RESEARCH   BMC HEALTH SERV RES                     BMC  1472-6963  1472-6963  HEALTH CARE SCIENCES & SERVICES    SCIE          42,261      3.0           Q2      0.99          99.72%   55/185        3.4                  Q2                    2.8             0.4   53/185           Q2           71.62      0.04775                10.62526                    0.939            70.5           Q2   70/169         1,644                         96.53%              5.6               6.5          1,587
# 3  JOURNAL OF GENERAL INTERNAL MEDICINE      J GEN INTERN MED                SPRINGER  1478-4491  1525-1497  HEALTH CARE SCIENCES & SERVICES    SCIE          32,058      4.2           Q1      1.34          27.74%   25/185        5.4                  Q1                    3.9             0.5   23/185           Q1           87.84      0.03908                 8.69694                    2.216            86.8           Q1   12/169           472                         91.74%              9.4               6.1            433
# 4      BMC Medical Research Methodology  BMC MED RES METHODOL                     BMC  1471-2288  1471-2288  HEALTH CARE SCIENCES & SERVICES    SCIE          27,987      3.4           Q1      1.19          99.46%   37/185        5.2                  Q1                    3.3             0.5   30/185           Q1           84.05      0.02213                 4.92442                    1.971            80.3           Q1   20/169           316                         97.78%              9.6               8.1            309
# ┌──────────────────────┬──────────────────────┬───┬─────────────────┬──────────────────┬────────────────┐
# │     Journal name     │   JCR Abbreviation   │ … │ Cited Half-Life │ Citing Half-Life │ Total Articles │
# │       varchar        │       varchar        │   │     double      │      double      │    varchar     │
# ├──────────────────────┼──────────────────────┼───┼─────────────────┼──────────────────┼────────────────┤
# │ JOURNAL OF MEDICAL…  │ J MED INTERNET RES   │ … │             4.5 │              5.6 │ 766            │
# │ JOURNAL OF CLINICA…  │ J CLIN EPIDEMIOL     │ … │            13.6 │              6.4 │ 171            │
# │ BMC HEALTH SERVICE…  │ BMC HEALTH SERV RES  │ … │             5.6 │              6.5 │ 1,587          │
# │ JOURNAL OF GENERAL…  │ J GEN INTERN MED     │ … │             9.4 │              6.1 │ 433            │
# │ BMC Medical Resear…  │ BMC MED RES METHODOL │ … │             9.6 │              8.1 │ 309            │
# │ Healthcare           │ HEALTHCARE-BASEL     │ … │             2.4 │              6.5 │ 2,094          │
# │ SUPPORTIVE CARE IN…  │ SUPPORT CARE CANCER  │ … │             5.5 │              6.7 │ 652            │
# │ ACADEMIC MEDICINE    │ ACAD MED             │ … │             9.5 │              7.0 │ 251            │
# │ QUALITY OF LIFE RE…  │ QUAL LIFE RES        │ … │             9.5 │              7.6 │ 243            │
# │ Implementation Sci…  │ IMPLEMENT SCI        │ … │             9.2 │              6.8 │ 56             │
# │          ·           │       ·              │ · │              ·  │               ·  │ ·              │
# │          ·           │       ·              │ · │              ·  │               ·  │ ·              │
# │          ·           │       ·              │ · │              ·  │               ·  │ ·              │
# │ International Jour…  │ INT J HEALTH GOV     │ … │             3.5 │              5.6 │ 32             │
# │ Asia Pacific Journ…  │ ASIA-PAC J HEALTH MA │ … │             3.7 │              6.7 │ 88             │
# │ IISE Transactions …  │ IISE T HEALTHC SYST  │ … │             3.7 │              9.2 │ 16             │
# │ Journal of Patient…  │ J PATIENT SAF RISK M │ … │             3.9 │              7.1 │ 33             │
# │ International Jour…  │ INT J SOC DETER HLTH │ … │             1.3 │              7.7 │ 37             │
# │ SCIENCES SOCIALES …  │ SCI SOC SANTE        │ … │            16.6 │              9.5 │ 15             │
# │ Asian Journal of W…  │ ASIAN J WTO INT HEAL │ … │            NULL │              6.4 │ 16             │
# │ Avicenna             │ AVICENNA             │ … │            NULL │              5.8 │ 7              │
# │ Journal of Medicin…  │ J MED ACCESS         │ … │            NULL │              7.6 │ 11             │
# │ Farmaceuticos Comu…  │ FARM COMUNITARIOS    │ … │            NULL │              6.8 │ 20             │
# ├──────────────────────┴──────────────────────┴───┴─────────────────┴──────────────────┴────────────────┤
# │ 3543 rows (20 shown)                                                             31 columns (5 shown) │
# └───────────────────────────────────────────────────────────────────────────────────────────────────────┘
#
# df.shape = (613, 4)
#                             journal  acr  pub  journal_score
# 0    QUARTERLY JOURNAL OF ECONOMICS  BCK   40          10.00
# 1          AMERICAN ECONOMIC REVIEW  ACE  116           8.40
# 2      ACADEMY OF MANAGEMENT ANNALS  HPA   31           7.04
# 3        NBER MACROECONOMICS ANNUAL  CGO    7           6.46
# 4  ADMINISTRATIVE SCIENCE QUARTERLY  DHW   39           6.40
# ┌──────────────────────────────────────────────┬─────────┬───────┬───────────────┐
# │                   journal                    │   acr   │  pub  │ journal_score │
# │                   varchar                    │ varchar │ int64 │    double     │
# ├──────────────────────────────────────────────┼─────────┼───────┼───────────────┤
# │ QUARTERLY JOURNAL OF ECONOMICS               │ BCK     │    40 │          10.0 │
# │ AMERICAN ECONOMIC REVIEW                     │ ACE     │   116 │           8.4 │
# │ ACADEMY OF MANAGEMENT ANNALS                 │ HPA     │    31 │          7.04 │
# │ NBER MACROECONOMICS ANNUAL                   │ CGO     │     7 │          6.46 │
# │ ADMINISTRATIVE SCIENCE QUARTERLY             │ DHW     │    39 │           6.4 │
# │ REVIEW OF ECONOMIC STUDIES                   │ AEM     │    80 │          5.99 │
# │ JOURNAL OF POLITICAL ECONOMY                 │ ACO     │   110 │          5.74 │
# │ ECONOMETRICA                                 │ AEU     │    76 │          5.32 │
# │ JOURNAL OF FINANCE                           │ ADN     │    73 │          5.01 │
# │ AMERICAN ECONOMIC REVIEW-INSIGHTS            │ BFA     │    32 │          4.72 │
# │                 ·                            │  ·      │     · │            ·  │
# │                 ·                            │  ·      │     · │            ·  │
# │                 ·                            │  ·      │     · │            ·  │
# │ HITOTSUBASHI JOURNAL OF ECONOMICS            │ CGM     │     8 │          0.05 │
# │ INDEPENDENT REVIEW                           │ BCV     │    40 │          0.05 │
# │ INTERNATIONAL JOURNAL OF TRANSPORT ECONOMICS │ CCG     │    20 │          0.05 │
# │ INVESTIGACION ECONOMICA                      │ CCE     │    20 │          0.05 │
# │ KOREAN ECONOMIC REVIEW                       │ CEC     │    15 │          0.05 │
# │ MILITARY OPERATIONS RESEARCH                 │ HGR     │    17 │          0.05 │
# │ POLITICKA EKONOMIE                           │ BGL     │    29 │          0.05 │
# │ REVIEW OF NETWORK ECONOMICS                  │ CGS     │     6 │          0.05 │
# │ REVUE D ETUDES COMPARATIVES EST-OUEST        │ CCR     │    19 │          0.05 │
# │ TRIMESTRE ECONOMICO                          │ BDI     │    37 │          0.05 │
# ├──────────────────────────────────────────────┴─────────┴───────┴───────────────┤
# │ 613 rows (20 shown)                                                  4 columns │
# └────────────────────────────────────────────────────────────────────────────────┘
#
# df.shape = (600, 4)
#                                     institution  acr  pub  iscore
# 0  Center for Economic & Policy Research (CEPR)  CBM  158    8.00
# 1                         University of Chicago  AAU  203    7.88
# 2                        London Business School  ABF   61    7.33
# 3                          Princeton University  AAN  113    7.19
# 4        University of California Santa Barbara  ACZ   56    6.86
# ┌──────────────────────────────────────────────┬─────────┬───────┬────────┐
# │                 institution                  │   acr   │  pub  │ iscore │
# │                   varchar                    │ varchar │ int64 │ double │
# ├──────────────────────────────────────────────┼─────────┼───────┼────────┤
# │ Center for Economic & Policy Research (CEPR) │ CBM     │   158 │    8.0 │
# │ University of Chicago                        │ AAU     │   203 │   7.88 │
# │ London Business School                       │ ABF     │    61 │   7.33 │
# │ Princeton University                         │ AAN     │   113 │   7.19 │
# │ University of California Santa Barbara       │ ACZ     │    56 │   6.86 │
# │ Stanford University                          │ AAO     │   273 │   6.58 │
# │ Massachusetts Institute of Technology (MIT)  │ AAI     │   244 │   6.37 │
# │ Yale University                              │ AAY     │   165 │   6.15 │
# │ National Bureau of Economic Research         │ AAK     │   724 │   5.99 │
# │ Harvard University                           │ AAF     │   430 │   5.87 │
# │        ·                                     │  ·      │     · │     ·  │
# │        ·                                     │  ·      │     · │     ·  │
# │        ·                                     │  ·      │     · │     ·  │
# │ Kobe University                              │ ACJ     │    68 │   1.07 │
# │ Universidade Federal do Rio Grande do Sul    │ AHN     │    38 │   1.07 │
# │ Universidade de Vigo                         │ CCI     │    40 │   1.07 │
# │ University of Piraeus                        │ BGC     │    43 │   1.07 │
# │ Islamic Azad University                      │ DEY     │    58 │   1.05 │
# │ Feng Chia University                         │ DDU     │    42 │   1.03 │
# │ Bucharest University of Economic Studies     │ CBO     │   109 │   1.02 │
# │ University of Belgrade                       │ DDE     │    43 │   1.01 │
# │ Vilnius Gediminas Technical University       │ BGX     │    48 │   1.01 │
# │ University of Novi Sad                       │ DEB     │    42 │    1.0 │
# ├──────────────────────────────────────────────┴─────────┴───────┴────────┤
# │ 600 rows (20 shown)                                           4 columns │
# └─────────────────────────────────────────────────────────────────────────┘
#
# df.shape = (600, 5)
#                                     institution  acr  pub  iscore                        institution_normal
# 0  Center for Economic & Policy Research (CEPR)  CBM  158    8.00  Center for Economic and Policy Research
# 1                         University of Chicago  AAU  203    7.88                     University of Chicago
# 2                        London Business School  ABF   61    7.33                    London Business School
# 3                          Princeton University  AAN  113    7.19                      Princeton University
# 4        University of California Santa Barbara  ACZ   56    6.86    University of California Santa Barbara
# MISSED Pompeu Fabra University Pompeu Fabra University
# MISSED Centre for Economic Policy Research UK Centre for Economic Policy Research - UK
# MISSED INSEAD Business School INSEAD Business School
# MISSED Hautes Etudes Commerciales  Paris Hautes Etudes Commerciales (HEC) Paris
# MISSED University of Texas Austin University of Texas Austin
# MISSED University of North Carolina Chapel Hill University of North Carolina Chapel Hill
# MISSED Federal Reserve System USA Federal Reserve System - USA
# MISSED London School Economics and Political Science London School Economics & Political Science
# MISSED IZA Institute Labor Economics IZA Institute Labor Economics
# MISSED Rutgers University Newark Rutgers University Newark
# MISSED Universite Catholique Louvain Universite Catholique Louvain
# MISSED University of Texas Dallas University of Texas Dallas
# MISSED York University Canada York University - Canada
# MISSED Texas AandM University College Station Texas A&M University College Station
# MISSED Arizona State University-Tempe Arizona State University-Tempe
# MISSED Pontificia Universidad Catolica de Chile Pontificia Universidad Catolica de Chile
# MISSED Queen Mary University London Queen Mary University London
# MISSED Leuphana University Luneburg Leuphana University Luneburg
# MISSED Universite Toulouse 1 Capitole Universite Toulouse 1 Capitole
# MISSED University of South Carolina Columbia University of South Carolina Columbia
# MISSED Queens University Canada Queens University - Canada
# MISSED University of Tennessee Knoxville University of Tennessee Knoxville
# MISSED Rutgers University New Brunswick Rutgers University New Brunswick
# MISSED City St Georges University of London City St Georges, University of London
# MISSED University of St Gallen University of St Gallen
# MISSED Jonkoping University Jonkoping University
# MISSED Lappeenranta-Lahti University of Technology LUT Lappeenranta-Lahti University of Technology LUT
# MISSED Luiss Guido Carli University Luiss Guido Carli University
# MISSED University of Arkansas Fayetteville University of Arkansas Fayetteville
# MISSED The Chinese University of Hong Kong Shenzhen The Chinese University of Hong Kong, Shenzhen
# MISSED Tecnologico de Monterrey Tecnologico de Monterrey
# MISSED heSam Universite heSam Universite
# MISSED Universite de Montreal Universite de Montreal
# MISSED Oklahoma State University Stillwater Oklahoma State University - Stillwater
# MISSED University of North Carolina Charlotte University of North Carolina Charlotte
# MISSED Autonomous University of Barcelona Autonomous University of Barcelona
# MISSED Royal Holloway University London Royal Holloway University London
# MISSED University of North Carolina Greensboro University of North Carolina Greensboro
# MISSED Virginia Polytechnic Institute and State University Virginia Polytechnic Institute & State University
# MISSED University of Oklahoma Norman University of Oklahoma - Norman
# MISSED University of Hamburg University of Hamburg
# MISSED The World Bank The World Bank
# MISSED Charles University Prague Charles University Prague
# MISSED Ihsan Dogramaci Bilkent University Ihsan Dogramaci Bilkent University
# MISSED Humboldt University of Berlin Humboldt University of Berlin
# MISSED Kings College London King's College London
# MISSED University of Innsbruck University of Innsbruck
# MISSED University of New South Wales Sydney University of New South Wales Sydney
# MISSED Free University of Berlin Free University of Berlin
# MISSED Technische Universitat Dresden Technische Universitat Dresden
# MISSED Concordia University Canada Concordia University - Canada
# MISSED University of Munster University of Munster
# MISSED Universite Cote dAzur Universite Cote d'Azur
# MISSED DIW Berlin Deutsches Institut fur Wirtschaftsforschung DIW Berlin - Deutsches Institut fur Wirtschaftsforschung
# MISSED Scuola Superiore SantAnna Scuola Superiore Sant'Anna
# MISSED University of Alabama Tuscaloosa University of Alabama Tuscaloosa
# MISSED Linkoping University Linkoping University
# MISSED Binghamton University SUNY Binghamton University, SUNY
# MISSED Open University UK Open University - UK
# MISSED University of Basque Country University of Basque Country
# MISSED University Hohenheim University Hohenheim
# MISSED Victoria University Wellington Victoria University Wellington
# MISSED Newcastle University UK Newcastle University - UK
# MISSED Johannes Kepler University Linz Johannes Kepler University Linz
# MISSED Parthenope University Naples Parthenope University Naples
# MISSED Texas State University San Marcos Texas State University San Marcos
# MISSED Technical University of Berlin Technical University of Berlin
# MISSED G dAnnunzio University of Chieti-Pescara G d'Annunzio University of Chieti-Pescara
# MISSED Ruprecht Karls University Heidelberg Ruprecht Karls University Heidelberg
# MISSED Getulio Vargas Foundation Getulio Vargas Foundation
# MISSED Queens University Belfast Queens University Belfast
# MISSED Universite Libre de Bruxelles Universite Libre de Bruxelles
# MISSED University at Albany SUNY University at Albany, SUNY
# MISSED University of Gottingen University of Gottingen
# MISSED University of North Texas Denton University of North Texas Denton
# MISSED Universita Ca Foscari Venezia Universita Ca Foscari Venezia
# MISSED Universite Claude Bernard Lyon 1 Universite Claude Bernard Lyon 1
# MISSED University of West England University of West England
# MISSED University of Zaragoza University of Zaragoza
# MISSED Zentrum fur Europaische Wirtschaftsforschung  Zentrum fur Europaische Wirtschaftsforschung (ZEW)
# MISSED Southwestern University of Finance and Economics China Southwestern University of Finance & Economics - China
# MISSED Universite de Montpellier Universite de Montpellier
# MISSED University of York UK University of York - UK
# MISSED Ho Chi Minh City University Economics Ho Chi Minh City University Economics
# MISSED Universite PSL Universite PSL
# MISSED University of Barcelona University of Barcelona
# MISSED Xian Jiaotong-Liverpool University Xi'an Jiaotong-Liverpool University
# MISSED Consejo Superior de Investigaciones Cientificas  Consejo Superior de Investigaciones Cientificas (CSIC)
# MISSED University of Kiel University of Kiel
# MISSED Catholic University of the Sacred Heart Catholic University of the Sacred Heart
# MISSED Universite de Rennes Universite de Rennes
# MISSED Aix-Marseille Universite Aix-Marseille Universite
# MISSED Universitat Politecnica de Valencia Universitat Politecnica de Valencia
# MISSED Universite de Strasbourg Universite de Strasbourg
# MISSED Universita degli Studi di Bari Aldo Moro Universita degli Studi di Bari Aldo Moro
# MISSED University of Sevilla University of Sevilla
# MISSED Northeastern University China Northeastern University - China
# MISSED Autonomous University of Madrid Autonomous University of Madrid
# MISSED Universite de Lille Universite de Lille
# MISSED Complutense University of Madrid Complutense University of Madrid
# MISSED Sapienza University Rome Sapienza University Rome
# MISSED Universite de Lorraine Universite de Lorraine
# MISSED University of Quebec Montreal University of Quebec Montreal
# MISSED Poznan University of Economics and Business Poznan University of Economics & Business
# MISSED HSE University  HSE University (National Research University Higher School of Economics)
# MISSED Universite Paris Saclay Universite Paris Saclay
# MISSED Universitat dAlacant Universitat d'Alacant
# MISSED Academia Sinica Taiwan Academia Sinica - Taiwan
# MISSED Guangdong University of Finance and Economics Guangdong University of Finance & Economics
# MISSED Southeast University China Southeast University - China
# MISSED Universidad de Malaga Universidad de Malaga
# MISSED University of Witwatersrand University of Witwatersrand
# MISSED Universidade de Sao Paulo Universidade de Sao Paulo
# MISSED Corvinus University Budapest Corvinus University Budapest
# MISSED Universite Grenoble Alpes  Universite Grenoble Alpes (UGA)
# MISSED University of Bielefeld University of Bielefeld
# MISSED University of Economics Bratislava University of Economics Bratislava
# MISSED Universite de Sfax Universite de Sfax
# matched.shape = (482, 10)
#                                  id                                      esi_name                  short_id                             display_name                hint  cited_by_count  works_count  entity_type                external_id                        filter_key
# 0  https://openalex.org/I1279858714  Center for Economic & Policy Research (CEPR)  institutions/I1279858714  Center for Economic and Policy Research     Washington, USA          350217         4917  institution  https://ror.org/01vqjmx11  authorships.institutions.lineage
# 0    https://openalex.org/I40347166                         University of Chicago    institutions/I40347166                    University of Chicago        Chicago, USA        13646246       265690  institution  https://ror.org/024mw5h28  authorships.institutions.lineage
# 0    https://openalex.org/I61544103                        London Business School    institutions/I61544103                   London Business School          London, UK          572457         8773  institution  https://ror.org/001c2sn75  authorships.institutions.lineage
# 0    https://openalex.org/I20089843                          Princeton University    institutions/I20089843                     Princeton University      Princeton, USA        10941802       190178  institution  https://ror.org/00hx57361  authorships.institutions.lineage
# 0   https://openalex.org/I154570441        University of California Santa Barbara   institutions/I154570441  University of California, Santa Barbara  Santa Barbara, USA         6474587       124185  institution  https://ror.org/02t274463  authorships.institutions.lineage
# unmatched.shape = (118, 5)
#                                  institution  acr  pub  iscore                      institution_normal
# 13                   Pompeu Fabra University  AGW   80    5.16                 Pompeu Fabra University
# 15  Centre for Economic Policy Research - UK  ACC  253    5.01  Centre for Economic Policy Research UK
# 17                    INSEAD Business School  CAA   89    4.98                  INSEAD Business School
# 26    Hautes Etudes Commerciales (HEC) Paris  AEU   58    4.03       Hautes Etudes Commerciales  Paris
# 28                University of Texas Austin  ADQ  123    3.96              University of Texas Austin
# df.shape = (118, 5)
#                                  institution  acr  pub  iscore                      institution_normal
# 13                   Pompeu Fabra University  AGW   80    5.16                 Pompeu Fabra University
# 15  Centre for Economic Policy Research - UK  ACC  253    5.01  Centre for Economic Policy Research UK
# 17                    INSEAD Business School  CAA   89    4.98                  INSEAD Business School
# 26    Hautes Etudes Commerciales (HEC) Paris  AEU   58    4.03       Hautes Etudes Commerciales  Paris
# 28                University of Texas Austin  ADQ  123    3.96              University of Texas Austin
# ┌────────────────────────────────────────────────────┬───────────────────────────┐
# │                        name                        │      institution_id       │
# │                      varchar                       │          varchar          │
# ├────────────────────────────────────────────────────┼───────────────────────────┤
# │ Monash University                                  │ https://ror.org/02bfwt286 │
# │ Macquarie University                               │ https://ror.org/01sf06y89 │
# │ Wollongong University                              │ https://ror.org/00jtmb277 │
# │ University of Wollongong                           │ https://ror.org/00jtmb277 │
# │ University of Tasmania                             │ https://ror.org/01nfmeh72 │
# │ Flinders University                                │ https://ror.org/01kpzv902 │
# │ Flinders University of South Australia             │ https://ror.org/01kpzv902 │
# │ RMIT University                                    │ https://ror.org/04ttjf776 │
# │ Royal Melbourne Institute of Technology University │ https://ror.org/04ttjf776 │
# │ La Trobe University                                │ https://ror.org/01rxfrp27 │
# │          ·                                         │             ·             │
# │          ·                                         │             ·             │
# │          ·                                         │             ·             │
# │ The British Petroleum Company                      │ https://ror.org/01zctcs90 │
# │ BP (United Kingdom)                                │ https://ror.org/01zctcs90 │
# │ BP Amoco                                           │ https://ror.org/01zctcs90 │
# │ Rio Tinto (United Kingdom)                         │ https://ror.org/05m7zw681 │
# │ Department of Water                                │ https://ror.org/017wrhq72 │
# │ Department of Water and Environmental Regulation   │ https://ror.org/017wrhq72 │
# │ BAE Systems (United Kingdom)                       │ https://ror.org/04p8ejq70 │
# │ Ove N. Arup Consulting Engineers                   │ https://ror.org/03awtex73 │
# │ Arup Group (United States)                         │ https://ror.org/03awtex73 │
# │ Arup                                               │ https://ror.org/03awtex73 │
# ├────────────────────────────────────────────────────┴───────────────────────────┤
# │ 44 rows (20 shown)                                                   2 columns │
# └────────────────────────────────────────────────────────────────────────────────┘
#
#                        name             institution_id
# 0         Monash University  https://ror.org/02bfwt286
# 1      Macquarie University  https://ror.org/01sf06y89
# 2     Wollongong University  https://ror.org/00jtmb277
# 3  University of Wollongong  https://ror.org/00jtmb277
# 4    University of Tasmania  https://ror.org/01nfmeh72
# MISSED  Pompeu Fabra University 0
# MISSED  Centre for Economic Policy Research - UK 1
# MISSED  INSEAD Business School 2
# MISSED  Hautes Etudes Commerciales (HEC) Paris 3
# MISSED  University of Texas Austin 4
# MISSED  University of North Carolina Chapel Hill 5
# MISSED  Federal Reserve System - USA 6
# MISSED  London School Economics & Political Science 7
# MISSED  IZA Institute Labor Economics 8
# MISSED  Rutgers University Newark 9
# MISSED  Universite Catholique Louvain 10
# MISSED  University of Texas Dallas 11
# MISSED  York University - Canada 12
# MISSED  Texas A&M University College Station 13
# MISSED  Arizona State University-Tempe 14
# MISSED  Pontificia Universidad Catolica de Chile 15
# MISSED  Queen Mary University London 16
# MISSED  Leuphana University Luneburg 17
# MISSED  Universite Toulouse 1 Capitole 18
# MISSED  University of South Carolina Columbia 19
# MISSED  Queens University - Canada 20
# MISSED  University of Tennessee Knoxville 21
# MISSED  Rutgers University New Brunswick 22
# MISSED  City St Georges, University of London 23
# MISSED  University of St Gallen 24
# MISSED  Jonkoping University 25
# MISSED  Lappeenranta-Lahti University of Technology LUT 26
# MISSED  Luiss Guido Carli University 27
# MISSED  University of Arkansas Fayetteville 28
# MISSED  The Chinese University of Hong Kong, Shenzhen 29
# MISSED  Tecnologico de Monterrey 30
# MISSED  heSam Universite 31
# MISSED  Universite de Montreal 32
# MISSED  Oklahoma State University - Stillwater 33
# MISSED  University of North Carolina Charlotte 34
# MISSED  Autonomous University of Barcelona 35
# MISSED  Royal Holloway University London 36
# MISSED  University of North Carolina Greensboro 37
# MISSED  Virginia Polytechnic Institute & State University 38
# MISSED  University of Oklahoma - Norman 39
# MISSED  University of Hamburg 40
# MISSED  The World Bank 41
# MISSED  Charles University Prague 42
# MISSED  Ihsan Dogramaci Bilkent University 43
# MISSED  Humboldt University of Berlin 44
# MISSED  King's College London 45
# MISSED  University of Innsbruck 46
# MISSED  University of New South Wales Sydney 47
# MISSED  Free University of Berlin 48
# MISSED  Technische Universitat Dresden 49
# MISSED  Concordia University - Canada 50
# MISSED  University of Munster 51
# MISSED  Universite Cote d'Azur 52
# MISSED  DIW Berlin - Deutsches Institut fur Wirtschaftsforschung 53
# MISSED  Scuola Superiore Sant'Anna 54
# MISSED  University of Alabama Tuscaloosa 55
# MISSED  Linkoping University 56
# MISSED  Binghamton University, SUNY 57
# MISSED  Open University - UK 58
# MISSED  University of Basque Country 59
# MISSED  University Hohenheim 60
# MISSED  Victoria University Wellington 61
# MISSED  Newcastle University - UK 62
# MISSED  Johannes Kepler University Linz 63
# MISSED  Parthenope University Naples 64
# MISSED  Texas State University San Marcos 65
# MISSED  Technical University of Berlin 66
# MISSED  G d'Annunzio University of Chieti-Pescara 67
# MISSED  Ruprecht Karls University Heidelberg 68
# MISSED  Getulio Vargas Foundation 69
# MISSED  Queens University Belfast 70
# MISSED  Universite Libre de Bruxelles 71
# MISSED  University at Albany, SUNY 72
# MISSED  University of Gottingen 73
# MISSED  University of North Texas Denton 74
# MISSED  Universita Ca Foscari Venezia 75
# MISSED  Universite Claude Bernard Lyon 1 76
# MISSED  University of West England 77
# MISSED  University of Zaragoza 78
# MISSED  Zentrum fur Europaische Wirtschaftsforschung (ZEW) 79
# MISSED  Southwestern University of Finance & Economics - China 80
# MISSED  Universite de Montpellier 81
# MISSED  University of York - UK 82
# MISSED  Ho Chi Minh City University Economics 83
# MISSED  Universite PSL 84
# MISSED  University of Barcelona 85
# MISSED  Xi'an Jiaotong-Liverpool University 86
# MISSED  Consejo Superior de Investigaciones Cientificas (CSIC) 87
# MISSED  University of Kiel 88
# MISSED  Catholic University of the Sacred Heart 89
# MISSED  Universite de Rennes 90
# MISSED  Aix-Marseille Universite 91
# MISSED  Universitat Politecnica de Valencia 92
# MISSED  Universite de Strasbourg 93
# MISSED  Universita degli Studi di Bari Aldo Moro 94
# MISSED  University of Sevilla 95
# MISSED  Northeastern University - China 96
# MISSED  Autonomous University of Madrid 97
# MISSED  Universite de Lille 98
# MISSED  Complutense University of Madrid 99
# MISSED  Sapienza University Rome 100
# MISSED  Universite de Lorraine 101
# MISSED  University of Quebec Montreal 102
# MISSED  Poznan University of Economics & Business 103
# MISSED  HSE University (National Research University Higher School of Economics) 104
# MISSED  Universite Paris Saclay 105
# MISSED  Universitat d'Alacant 106
# MISSED  Academia Sinica - Taiwan 107
# MISSED  Guangdong University of Finance & Economics 108
# MISSED  Southeast University - China 109
# MISSED  Universidad de Malaga 110
# MISSED  University of Witwatersrand 111
# MISSED  Universidade de Sao Paulo 112
# MISSED  Corvinus University Budapest 113
# MISSED  Universite Grenoble Alpes (UGA) 114
# MISSED  University of Bielefeld 115
# MISSED  University of Economics Bratislava 116
# MISSED  Universite de Sfax 117
# DONE
